# %% [markdown]
# <a href="https://colab.research.google.com/github/PratikStar/google-colab/blob/main/1_2_Create_Audio_Spectrogram_(Windowed_version).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Pipeline Classes

# %%
"""
1- load a file..
2- pad the signal (if necessary)
3- extracting log spectrogram from signal
4- normalise spectrogram
5- save the normalised spectrogram

PreprocessingPipeline
"""
import os
import pickle
import re
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import inspect
import soundfile as sf

SHOW_LOGS = True
LOG_LEVEL = 1
def log(logline, log_level = 1):
    if SHOW_LOGS and log_level <= LOG_LEVEL:
        stack = inspect.stack()
        the_class = stack[1][0].f_locals["self"].__class__.__name__
        the_method = stack[1][0].f_code.co_name
        print(the_class + ": " + logline)

class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, offset, load_duration, window_duration, mono):
        self.sample_rate = sample_rate
        self.load_duration = load_duration
        self.window_duration = window_duration
        self.offset = offset
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              duration=self.load_duration,
                              offset=self.offset,
                              mono=self.mono)[0]
        log("Shape of the loaded signal: " + str(signal.shape), 2)
        log("Mean of the loaded signal: " + str(np.mean(signal)), 5)
        log("Min of the loaded signal: " + str(np.amin(signal)), 5)
        log("Max of the loaded signal: " + str(np.amax(signal)), 5)
        log("Raw signal: " + str(signal), 5)
        return signal


class Padder:
    """Padder is responsible to apply padding to an array."""

    def __init__(self, mode="constant"):
        self.mode = mode

    def left_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (num_missing_items, 0),
                              mode=self.mode)
        return padded_array

    def right_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (0, num_missing_items),
                              mode=self.mode)
        return padded_array


class LogSpectrogramExtractor:
    """LogSpectrogramExtractor extracts log spectrograms (in dB) from a
    time-series signal.
    """

    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length

    def extract(self, signal):
        stft = librosa.stft(signal,
                            n_fft=self.frame_size,
                            hop_length=self.hop_length)[:-1]
        log("Shape of stft: " + str(stft.shape), 2)
        spectrogram = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram

class FeatureExtractor:
    """ Extracts the required features"""

    def extract_ampid_from_name(self, filename):
        amp_id = int(filename.split('-')[0])
        log("Amp ID: " + str(amp_id), 5)
        return amp_id
    def extract_clipid_from_name(self, filename):
        clip_id = int(filename.split('-')[0])
        log("Clip ID: " + str(clip_id), 5)
        return clip_id

class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):

        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        log("Shape of norm_array: " + str(norm_array.shape), 2)
        log("Max of norm_array: " + str((array.max())), 5)
        log("Min of norm_array: " + str((array.min())), 5)
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array


class Saver:
    """saver is responsible to save features, and the min max values."""

    def __init__(self, feature_save_dir, min_max_values_save_dir):
        self.feature_save_dir = feature_save_dir
        Utils._create_folder_if_it_doesnt_exist(self.feature_save_dir)
        self.min_max_values_save_dir = min_max_values_save_dir

    def save_feature(self, feature, file_name):
        save_path = self._generate_save_path(file_name)
        np.save(save_path, feature)

    def save_min_max_values(self, min_max_values):
        save_path = os.path.join(self.min_max_values_save_dir,
                                 "min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_name):
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path

class Visualizer:
    def __init__(self, file_dir, frame_size, hop_length, offset):
        self.file_dir = file_dir
        self.frame_size = frame_size
        self.hop_length = hop_length
        self.offset = offset
        pass
    
    def visualize(self, spectrogram, file_name):
        plt.ioff()
        fig, ax = plt.subplots()
        try:
            img = librosa.display.specshow(spectrogram, y_axis='log', x_axis='time', ax=ax)
        except IndexError as e:
            log("Null spectrogram for file: " + file_name, 1)
            return
        ax.set_title("Frame Size: " + str(self.frame_size) + ", Hop Length: " + str(self.hop_length) + ", Offset: " + str(self.offset))
        fig.colorbar(img, ax=ax, format="%+2.0f dB")
        Utils._create_folder_if_it_doesnt_exist(self.file_dir)
        fig.savefig(os.path.join(self.file_dir, file_name + ".png"))
        plt.close(fig)

class Utils:
    def __init__(self):
        pass
    @staticmethod
    def _create_folder_if_it_doesnt_exist(folder):
        if not os.path.exists(folder):
            os.makedirs(folder)

class AudioReconstructor:
    """Processes stft inverse and saves the audio file"""
    def __init__(self, file_dir, hop_length, frame_size):
        self.file_dir = file_dir
        self.hop_length = hop_length
        self.frame_size = frame_size

    def reconstruct(self, features, file_name):
        # Invert using Griffin-Lim
        log("Shape of features: " + str(features.shape), 1)
        features_inv = librosa.griffinlim(features,
                                          hop_length=self.hop_length,
                                          win_length=self.frame_size)
        log("Shape of Inverse features: " + str(features_inv.shape), 1)
        Utils._create_folder_if_it_doesnt_exist(self.file_dir)
        sf.write(os.path.join(self.file_dir, file_name ), y_inv, 22050)
        # save audio
    def reconstruct_from_path(self, file_path):
        # Invert using Griffin-Lim
        features = np.load(file_path)
        self.reconstruct(features, os.path.basename(file_path))
    
class PreprocessingPipeline:
    """PreprocessingPipeline processes a single audio file, applying
    the following steps to each file:
        1- load a file
        2- pad the signal (if necessary)
        3- extracting log spectrogram from signal
        4- normalise spectrogram
        5- save the normalised spectrogram

    Storing the min max values for all the log spectrograms.
    """

    def __init__(self):
        self.padder = None
        self.extractor = None
        self.feature_extractor = None
        self.normaliser = None
        self.saver = None
        self.visualizer = None
        self.reconstructor = None
        self.min_max_values = {}
        self._loader = None
        self._num_expected_samples = None

    @property
    def loader(self):
        return self._loader

    @loader.setter
    def loader(self, loader):
        self._loader = loader
        self._num_expected_samples = int(loader.sample_rate * loader.window_duration)

    def process_file(self, audio_files_dir, audio_file_name, window_id, save_flg=True, visualize_flg=True, external_features_flg=False):

        # self._process_file(root, file, save_flg, visualize_flg, external_features_flg)

        file_path = os.path.join(audio_files_dir, audio_file_name)
        signal = self.loader.load(file_path)
        if external_features_flg:
            external_features = [ self.feature_extractor.extract_ampid_from_name(audio_file_name),
                                  self.feature_extractor.extract_clipid_from_name(audio_file_name),
                                  window_id                         
                                ]
            signal = np.concatenate((external_features, signal))

        if self._is_padding_necessary(signal):
            signal = self._apply_padding(signal)
        feature = self.extractor.extract(signal)

        norm_feature = self.normaliser.normalise(feature)
        name_split = audio_file_name.split(" ")
        file_name = name_split[0] + "-" + ('%02d' % (window_id)) + " " + " ".join(name_split[1:])
        print("\t" + file_name)
        if visualize_flg:
            self.visualizer.visualize(norm_feature, file_name)

        if save_flg:
            save_path = self.saver.save_feature(norm_feature, file_name)
            # self._store_min_max_value(save_path, feature.min(), feature.max())
        log(f"Processed file {audio_file_name}", 5)

        # self.saver.save_min_max_values(self.min_max_values)

    def _is_padding_necessary(self, signal):
        if len(signal) < self._num_expected_samples:
            log("Padding necessary", 5)
            log("Signal: " + str(len(signal)), 5)
            log("Exp samples: " + str(self._num_expected_samples), 5)
            return True
        return False

    def _apply_padding(self, signal):
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_value(self, save_path, min_val, max_val):
        self.min_max_values[save_path] = {
            "min": min_val,
            "max": max_val
        }

# %% [markdown]
# ## Driver Code

# %%
## TOBE <AMP_ID>-<CLIP_ID>-<WINDOW_ID> <AMP_NAME>.wav.npy
## 00000-06-00 DI.wav.png is not present

FRAME_SIZE = 512
HOP_LENGTH = FRAME_SIZE // 2 # smaller better?
OFFSET = 0
WINDOW_DURATION = 0.74  # in seconds
SAMPLE_RATE = 22050
MONO = True

# Dimensions: (FRAME_SIZE / 2) x ceil(SAMPLE_RATE * DURATION / HOP_LENGTH)

## SOURCE
AUDIO_FILES_DIR = "/content/drive/MyDrive/Music/VAE/audio/"
AUDIO_REGEX = "^(?!00000.*$).*\.wav$"

## OUTPUT
SPECTROGRAMS_SAVE_DIR = "/content/drive/MyDrive/Music/VAE/ICASSP/spectrogram/"
SPECTROGRAMS_IMG_SAVE_DIR = "/content/drive/MyDrive/Music/VAE/ICASSP/spectrogram-img/"
RECONSTRUCTED_AUDIO_SAVE_DIR = "/content/drive/MyDrive/Music/VAE/ICASSP/audio-reconstructed/"
MIN_MAX_VALUES_SAVE_DIR = "/content/drive/MyDrive/Music/VAE/ICASSP"

NUMBER_OF_CLIPS = 10000000

# instantiate all objects
# loader = Loader(SAMPLE_RATE, OFFSET, WINDOW_DURATION, MONO)
padder = Padder()
log_spectrogram_extractor = LogSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
feature_extractor = FeatureExtractor()
min_max_normaliser = MinMaxNormaliser(0, 1)
saver = Saver(SPECTROGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)
visualizer = Visualizer(SPECTROGRAMS_IMG_SAVE_DIR, FRAME_SIZE, HOP_LENGTH, OFFSET)
reconstructor = AudioReconstructor(RECONSTRUCTED_AUDIO_SAVE_DIR, HOP_LENGTH, FRAME_SIZE)

preprocessing_pipeline = PreprocessingPipeline()
# preprocessing_pipeline.loader = loader
preprocessing_pipeline.padder = padder
preprocessing_pipeline.extractor = log_spectrogram_extractor
preprocessing_pipeline.feature_extractor = feature_extractor
preprocessing_pipeline.normaliser = min_max_normaliser
preprocessing_pipeline.saver = saver
preprocessing_pipeline.reconstructor = reconstructor

number_of_clips = NUMBER_OF_CLIPS
for root, _, files in os.walk(AUDIO_FILES_DIR):
    for file in files:

        if re.match(AUDIO_REGEX, file) and number_of_clips > 0:
            print(file)
            number_of_clips -= 1
            y, sr = librosa.load(os.path.join(AUDIO_FILES_DIR, file), sr=SAMPLE_RATE, mono=MONO)
            duration = librosa.get_duration(y=y, sr=sr)
            window_id = 0
            while True:
                if (window_id) * WINDOW_DURATION >= duration:
                    break
                
                offset = window_id * WINDOW_DURATION
                loader = Loader(SAMPLE_RATE, offset, min(WINDOW_DURATION, duration - offset), WINDOW_DURATION, MONO)
                preprocessing_pipeline.loader = loader
                visualizer = Visualizer(SPECTROGRAMS_IMG_SAVE_DIR, FRAME_SIZE, HOP_LENGTH, offset)
                preprocessing_pipeline.visualizer = visualizer

                preprocessing_pipeline.process_file(AUDIO_FILES_DIR, file, window_id, save_flg=True, visualize_flg=True, external_features_flg=False)
                window_id += 1
# Out:
# 00001-11 01A US Double Nrm.wav
# 	00001-11-00 01A US Double Nrm.wav
# 	00001-11-01 01A US Double Nrm.wav
# 	00001-11-02 01A US Double Nrm.wav
# 	00001-11-03 01A US Double Nrm.wav
# 	00001-11-04 01A US Double Nrm.wav
# 	00001-11-05 01A US Double Nrm.wav
# 	00001-11-06 01A US Double Nrm.wav
# 	00001-11-07 01A US Double Nrm.wav
# 	00001-11-08 01A US Double Nrm.wav
# 00001-04 01A US Double Nrm.wav
# 	00001-04-00 01A US Double Nrm.wav
# 	00001-04-01 01A US Double Nrm.wav
# 	00001-04-02 01A US Double Nrm.wav
# 	00001-04-03 01A US Double Nrm.wav
# 	00001-04-04 01A US Double Nrm.wav
# 	00001-04-05 01A US Double Nrm.wav
# 	00001-04-06 01A US Double Nrm.wav
# 	00001-04-07 01A US Double Nrm.wav
# 	00001-04-08 01A US Double Nrm.wav
# 	00001-04-09 01A US Double Nrm.wav
# 	00001-04-10 01A US Double Nrm.wav
# 00001-06 01A US Double Nrm.wav
# 	00001-06-00 01A US Double Nrm.wav
# 	00001-06-01 01A US Double Nrm.wav
# 	00001-06-02 01A US Double Nrm.wav
# 	00001-06-03 01A US Double Nrm.wav
# 	00001-06-04 01A US Double Nrm.wav
# 	00001-06-05 01A US Double Nrm.wav
# 	00001-06-06 01A US Double Nrm.wav
# 	00001-06-07 01A US Double Nrm.wav
# 	00001-06-08 01A US Double Nrm.wav
# 	00001-06-09 01A US Double Nrm.wav
# 	00001-06-10 01A US Double Nrm.wav
# 	00001-06-11 01A US Double Nrm.wav
# 	00001-06-12 01A US Double Nrm.wav
# 	00001-06-13 01A US Double Nrm.wav
# 00001-09 01A US Double Nrm.wav
# 	00001-09-00 01A US Double Nrm.wav
# 	00001-09-01 01A US Double Nrm.wav
# 	00001-09-02 01A US Double Nrm.wav
# 	00001-09-03 01A US Double Nrm.wav
# 	00001-09-04 01A US Double Nrm.wav
# 	00001-09-05 01A US Double Nrm.wav
# 	00001-09-06 01A US Double Nrm.wav
# 	00001-09-07 01A US Double Nrm.wav
# 	00001-09-08 01A US Double Nrm.wav
# 	00001-09-09 01A US Double Nrm.wav
# 	00001-09-10 01A US Double Nrm.wav
# 00001-05 01A US Double Nrm.wav
# 	00001-05-00 01A US Double Nrm.wav
# 	00001-05-01 01A US Double Nrm.wav
# 	00001-05-02 01A US Double Nrm.wav
# 	00001-05-03 01A US Double Nrm.wav
# 	00001-05-04 01A US Double Nrm.wav
# 	00001-05-05 01A US Double Nrm.wav
# 	00001-05-06 01A US Double Nrm.wav
# 	00001-05-07 01A US Double Nrm.wav
# 	00001-05-08 01A US Double Nrm.wav
# 	00001-05-09 01A US Double Nrm.wav
# 	00001-05-10 01A US Double Nrm.wav
# 00001-12 01A US Double Nrm.wav
# 	00001-12-00 01A US Double Nrm.wav
# 	00001-12-01 01A US Double Nrm.wav
# 	00001-12-02 01A US Double Nrm.wav
# 	00001-12-03 01A US Double Nrm.wav
# 	00001-12-04 01A US Double Nrm.wav
# 	00001-12-05 01A US Double Nrm.wav
# 	00001-12-06 01A US Double Nrm.wav
# 	00001-12-07 01A US Double Nrm.wav
# 	00001-12-08 01A US Double Nrm.wav
# 	00001-12-09 01A US Double Nrm.wav
# 	00001-12-10 01A US Double Nrm.wav
# 	00001-12-11 01A US Double Nrm.wav
# 	00001-12-12 01A US Double Nrm.wav
# 	00001-12-13 01A US Double Nrm.wav
# 	00001-12-14 01A US Double Nrm.wav
# 00001-02 01A US Double Nrm.wav
# 	00001-02-00 01A US Double Nrm.wav
# 	00001-02-01 01A US Double Nrm.wav
# 	00001-02-02 01A US Double Nrm.wav
# 	00001-02-03 01A US Double Nrm.wav
# 	00001-02-04 01A US Double Nrm.wav
# 	00001-02-05 01A US Double Nrm.wav
# 	00001-02-06 01A US Double Nrm.wav
# 	00001-02-07 01A US Double Nrm.wav
# 	00001-02-08 01A US Double Nrm.wav
# 	00001-02-09 01A US Double Nrm.wav
# 	00001-02-10 01A US Double Nrm.wav
# 	00001-02-11 01A US Double Nrm.wav
# 00001-01 01A US Double Nrm.wav
# 	00001-01-00 01A US Double Nrm.wav
# 	00001-01-01 01A US Double Nrm.wav
# 	00001-01-02 01A US Double Nrm.wav
# 	00001-01-03 01A US Double Nrm.wav
# 	00001-01-04 01A US Double Nrm.wav
# 	00001-01-05 01A US Double Nrm.wav
# 	00001-01-06 01A US Double Nrm.wav
# 	00001-01-07 01A US Double Nrm.wav
# 	00001-01-08 01A US Double Nrm.wav
# 	00001-01-09 01A US Double Nrm.wav
# 	00001-01-10 01A US Double Nrm.wav
# 	00001-01-11 01A US Double Nrm.wav
# 	00001-01-12 01A US Double Nrm.wav
# 00001-07 01A US Double Nrm.wav
# 	00001-07-00 01A US Double Nrm.wav
# 	00001-07-01 01A US Double Nrm.wav
# 	00001-07-02 01A US Double Nrm.wav
# 	00001-07-03 01A US Double Nrm.wav
# 	00001-07-04 01A US Double Nrm.wav
# 	00001-07-05 01A US Double Nrm.wav
# 	00001-07-06 01A US Double Nrm.wav
# 	00001-07-07 01A US Double Nrm.wav
# 	00001-07-08 01A US Double Nrm.wav
# 	00001-07-09 01A US Double Nrm.wav
# 	00001-07-10 01A US Double Nrm.wav
# 00001-10 01A US Double Nrm.wav
# 	00001-10-00 01A US Double Nrm.wav
# 	00001-10-01 01A US Double Nrm.wav
# 	00001-10-02 01A US Double Nrm.wav
# 	00001-10-03 01A US Double Nrm.wav
# 	00001-10-04 01A US Double Nrm.wav
# 	00001-10-05 01A US Double Nrm.wav
# 	00001-10-06 01A US Double Nrm.wav
# 	00001-10-07 01A US Double Nrm.wav
# 00001-03 01A US Double Nrm.wav
# 	00001-03-00 01A US Double Nrm.wav
# 	00001-03-01 01A US Double Nrm.wav
# 	00001-03-02 01A US Double Nrm.wav
# 	00001-03-03 01A US Double Nrm.wav
# 	00001-03-04 01A US Double Nrm.wav
# 	00001-03-05 01A US Double Nrm.wav
# 	00001-03-06 01A US Double Nrm.wav
# 	00001-03-07 01A US Double Nrm.wav
# 	00001-03-08 01A US Double Nrm.wav
# 	00001-03-09 01A US Double Nrm.wav
# 	00001-03-10 01A US Double Nrm.wav
# 	00001-03-11 01A US Double Nrm.wav
# 	00001-03-12 01A US Double Nrm.wav
# 00001-08 01A US Double Nrm.wav
# 	00001-08-00 01A US Double Nrm.wav
# 	00001-08-01 01A US Double Nrm.wav
# 	00001-08-02 01A US Double Nrm.wav
# 	00001-08-03 01A US Double Nrm.wav
# 	00001-08-04 01A US Double Nrm.wav
# 	00001-08-05 01A US Double Nrm.wav
# 	00001-08-06 01A US Double Nrm.wav
# 	00001-08-07 01A US Double Nrm.wav
# 	00001-08-08 01A US Double Nrm.wav
# 	00001-08-09 01A US Double Nrm.wav
# 	00001-08-10 01A US Double Nrm.wav
# 	00001-08-11 01A US Double Nrm.wav
# 	00001-08-12 01A US Double Nrm.wav
# 	00001-08-13 01A US Double Nrm.wav
# 00002-09 01B Essex A30.wav
# 	00002-09-00 01B Essex A30.wav
# 	00002-09-01 01B Essex A30.wav
# 	00002-09-02 01B Essex A30.wav
# 	00002-09-03 01B Essex A30.wav
# 	00002-09-04 01B Essex A30.wav
# 	00002-09-05 01B Essex A30.wav
# 	00002-09-06 01B Essex A30.wav
# 	00002-09-07 01B Essex A30.wav
# 	00002-09-08 01B Essex A30.wav
# 	00002-09-09 01B Essex A30.wav
# 	00002-09-10 01B Essex A30.wav
# 00002-05 01B Essex A30.wav
# 	00002-05-00 01B Essex A30.wav
# 	00002-05-01 01B Essex A30.wav
# 	00002-05-02 01B Essex A30.wav
# 	00002-05-03 01B Essex A30.wav
# 	00002-05-04 01B Essex A30.wav
# 	00002-05-05 01B Essex A30.wav
# 	00002-05-06 01B Essex A30.wav
# 	00002-05-07 01B Essex A30.wav
# 	00002-05-08 01B Essex A30.wav
# 	00002-05-09 01B Essex A30.wav
# 	00002-05-10 01B Essex A30.wav
# 00002-04 01B Essex A30.wav
# 	00002-04-00 01B Essex A30.wav
# 	00002-04-01 01B Essex A30.wav
# 	00002-04-02 01B Essex A30.wav
# 	00002-04-03 01B Essex A30.wav
# 	00002-04-04 01B Essex A30.wav
# 	00002-04-05 01B Essex A30.wav
# 	00002-04-06 01B Essex A30.wav
# 	00002-04-07 01B Essex A30.wav
# 	00002-04-08 01B Essex A30.wav
# 	00002-04-09 01B Essex A30.wav
# 	00002-04-10 01B Essex A30.wav
# 00002-01 01B Essex A30.wav
# 	00002-01-00 01B Essex A30.wav
# 	00002-01-01 01B Essex A30.wav
# 	00002-01-02 01B Essex A30.wav
# 	00002-01-03 01B Essex A30.wav
# 	00002-01-04 01B Essex A30.wav
# 	00002-01-05 01B Essex A30.wav
# 	00002-01-06 01B Essex A30.wav
# 	00002-01-07 01B Essex A30.wav
# 	00002-01-08 01B Essex A30.wav
# 	00002-01-09 01B Essex A30.wav
# 	00002-01-10 01B Essex A30.wav
# 	00002-01-11 01B Essex A30.wav
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:111: RuntimeWarning: invalid value encountered in true_divide
# 	00002-01-12 01B Essex A30.wav
# Visualizer: Null spectrogram for file: 00002-01-12 01B Essex A30.wav
# 00002-11 01B Essex A30.wav
# 	00002-11-00 01B Essex A30.wav
# 	00002-11-01 01B Essex A30.wav
# 	00002-11-02 01B Essex A30.wav
# 	00002-11-03 01B Essex A30.wav
# 	00002-11-04 01B Essex A30.wav
# 	00002-11-05 01B Essex A30.wav
# 	00002-11-06 01B Essex A30.wav
# 	00002-11-07 01B Essex A30.wav
# 	00002-11-08 01B Essex A30.wav
# 00002-06 01B Essex A30.wav
# 	00002-06-00 01B Essex A30.wav
# 	00002-06-01 01B Essex A30.wav
# 	00002-06-02 01B Essex A30.wav
# 	00002-06-03 01B Essex A30.wav
# 	00002-06-04 01B Essex A30.wav
# 	00002-06-05 01B Essex A30.wav
# 	00002-06-06 01B Essex A30.wav
# 	00002-06-07 01B Essex A30.wav
# 	00002-06-08 01B Essex A30.wav
# 	00002-06-09 01B Essex A30.wav
# 	00002-06-10 01B Essex A30.wav
# 	00002-06-11 01B Essex A30.wav
# 	00002-06-12 01B Essex A30.wav
# 	00002-06-13 01B Essex A30.wav
# 00002-12 01B Essex A30.wav
# 	00002-12-00 01B Essex A30.wav
# 	00002-12-01 01B Essex A30.wav
# 	00002-12-02 01B Essex A30.wav
# 	00002-12-03 01B Essex A30.wav
# 	00002-12-04 01B Essex A30.wav
# 	00002-12-05 01B Essex A30.wav
# 	00002-12-06 01B Essex A30.wav
# 	00002-12-07 01B Essex A30.wav
# 	00002-12-08 01B Essex A30.wav
# 	00002-12-09 01B Essex A30.wav
# 	00002-12-10 01B Essex A30.wav
# 	00002-12-11 01B Essex A30.wav
# 	00002-12-12 01B Essex A30.wav
# 	00002-12-13 01B Essex A30.wav
# 	00002-12-14 01B Essex A30.wav
# 00002-08 01B Essex A30.wav
# 	00002-08-00 01B Essex A30.wav
# 	00002-08-01 01B Essex A30.wav
# 	00002-08-02 01B Essex A30.wav
# 	00002-08-03 01B Essex A30.wav
# 	00002-08-04 01B Essex A30.wav
# 	00002-08-05 01B Essex A30.wav
# 	00002-08-06 01B Essex A30.wav
# 	00002-08-07 01B Essex A30.wav
# 	00002-08-08 01B Essex A30.wav
# 	00002-08-09 01B Essex A30.wav
# 	00002-08-10 01B Essex A30.wav
# 	00002-08-11 01B Essex A30.wav
# 	00002-08-12 01B Essex A30.wav
# 	00002-08-13 01B Essex A30.wav
# 00002-07 01B Essex A30.wav
# 	00002-07-00 01B Essex A30.wav
# 	00002-07-01 01B Essex A30.wav
# 	00002-07-02 01B Essex A30.wav
# 	00002-07-03 01B Essex A30.wav
# 	00002-07-04 01B Essex A30.wav
# 	00002-07-05 01B Essex A30.wav
# 	00002-07-06 01B Essex A30.wav
# 	00002-07-07 01B Essex A30.wav
# 	00002-07-08 01B Essex A30.wav
# 	00002-07-09 01B Essex A30.wav
# 	00002-07-10 01B Essex A30.wav
# 00002-10 01B Essex A30.wav
# 	00002-10-00 01B Essex A30.wav
# 	00002-10-01 01B Essex A30.wav
# 	00002-10-02 01B Essex A30.wav
# 	00002-10-03 01B Essex A30.wav
# 	00002-10-04 01B Essex A30.wav
# 	00002-10-05 01B Essex A30.wav
# 	00002-10-06 01B Essex A30.wav
# 	00002-10-07 01B Essex A30.wav
# 00002-02 01B Essex A30.wav
# 	00002-02-00 01B Essex A30.wav
# 	00002-02-01 01B Essex A30.wav
# 	00002-02-02 01B Essex A30.wav
# 	00002-02-03 01B Essex A30.wav
# 	00002-02-04 01B Essex A30.wav
# 	00002-02-05 01B Essex A30.wav
# 	00002-02-06 01B Essex A30.wav
# 	00002-02-07 01B Essex A30.wav
# 	00002-02-08 01B Essex A30.wav
# 	00002-02-09 01B Essex A30.wav
# 	00002-02-10 01B Essex A30.wav
# 	00002-02-11 01B Essex A30.wav
# 00002-03 01B Essex A30.wav
# 	00002-03-00 01B Essex A30.wav
# 	00002-03-01 01B Essex A30.wav
# 	00002-03-02 01B Essex A30.wav
# 	00002-03-03 01B Essex A30.wav
# 	00002-03-04 01B Essex A30.wav
# 	00002-03-05 01B Essex A30.wav
# 	00002-03-06 01B Essex A30.wav
# 	00002-03-07 01B Essex A30.wav
# 	00002-03-08 01B Essex A30.wav
# 	00002-03-09 01B Essex A30.wav
# 	00002-03-10 01B Essex A30.wav
# 	00002-03-11 01B Essex A30.wav
# 	00002-03-12 01B Essex A30.wav
# 00003-09 01C Brit Plexi Jump.wav
# 	00003-09-00 01C Brit Plexi Jump.wav
# 	00003-09-01 01C Brit Plexi Jump.wav
# 	00003-09-02 01C Brit Plexi Jump.wav
# 	00003-09-03 01C Brit Plexi Jump.wav
# 	00003-09-04 01C Brit Plexi Jump.wav
# 	00003-09-05 01C Brit Plexi Jump.wav
# 	00003-09-06 01C Brit Plexi Jump.wav
# 	00003-09-07 01C Brit Plexi Jump.wav
# 	00003-09-08 01C Brit Plexi Jump.wav
# 	00003-09-09 01C Brit Plexi Jump.wav
# 	00003-09-10 01C Brit Plexi Jump.wav
# 00003-06 01C Brit Plexi Jump.wav
# 	00003-06-00 01C Brit Plexi Jump.wav
# 	00003-06-01 01C Brit Plexi Jump.wav
# 	00003-06-02 01C Brit Plexi Jump.wav
# 	00003-06-03 01C Brit Plexi Jump.wav
# 	00003-06-04 01C Brit Plexi Jump.wav
# 	00003-06-05 01C Brit Plexi Jump.wav
# 	00003-06-06 01C Brit Plexi Jump.wav
# 	00003-06-07 01C Brit Plexi Jump.wav
# 	00003-06-08 01C Brit Plexi Jump.wav
# 	00003-06-09 01C Brit Plexi Jump.wav
# 	00003-06-10 01C Brit Plexi Jump.wav
# 	00003-06-11 01C Brit Plexi Jump.wav
# 	00003-06-12 01C Brit Plexi Jump.wav
# 	00003-06-13 01C Brit Plexi Jump.wav
# 00003-11 01C Brit Plexi Jump.wav
# 	00003-11-00 01C Brit Plexi Jump.wav
# 	00003-11-01 01C Brit Plexi Jump.wav
# 	00003-11-02 01C Brit Plexi Jump.wav
# 	00003-11-03 01C Brit Plexi Jump.wav
# 	00003-11-04 01C Brit Plexi Jump.wav
# 	00003-11-05 01C Brit Plexi Jump.wav
# 	00003-11-06 01C Brit Plexi Jump.wav
# 	00003-11-07 01C Brit Plexi Jump.wav
# 	00003-11-08 01C Brit Plexi Jump.wav
# 00003-10 01C Brit Plexi Jump.wav
# 	00003-10-00 01C Brit Plexi Jump.wav
# 	00003-10-01 01C Brit Plexi Jump.wav
# 	00003-10-02 01C Brit Plexi Jump.wav
# 	00003-10-03 01C Brit Plexi Jump.wav
# 	00003-10-04 01C Brit Plexi Jump.wav
# 	00003-10-05 01C Brit Plexi Jump.wav
# 	00003-10-06 01C Brit Plexi Jump.wav
# 	00003-10-07 01C Brit Plexi Jump.wav
# 00003-05 01C Brit Plexi Jump.wav
# 	00003-05-00 01C Brit Plexi Jump.wav
# 	00003-05-01 01C Brit Plexi Jump.wav
# 	00003-05-02 01C Brit Plexi Jump.wav
# 	00003-05-03 01C Brit Plexi Jump.wav
# 	00003-05-04 01C Brit Plexi Jump.wav
# 	00003-05-05 01C Brit Plexi Jump.wav
# 	00003-05-06 01C Brit Plexi Jump.wav
# 	00003-05-07 01C Brit Plexi Jump.wav
# 	00003-05-08 01C Brit Plexi Jump.wav
# 	00003-05-09 01C Brit Plexi Jump.wav
# 	00003-05-10 01C Brit Plexi Jump.wav
# 00003-12 01C Brit Plexi Jump.wav
# 	00003-12-00 01C Brit Plexi Jump.wav
# 	00003-12-01 01C Brit Plexi Jump.wav
# 	00003-12-02 01C Brit Plexi Jump.wav
# 	00003-12-03 01C Brit Plexi Jump.wav
# 	00003-12-04 01C Brit Plexi Jump.wav
# 	00003-12-05 01C Brit Plexi Jump.wav
# 	00003-12-06 01C Brit Plexi Jump.wav
# 	00003-12-07 01C Brit Plexi Jump.wav
# 	00003-12-08 01C Brit Plexi Jump.wav
# 	00003-12-09 01C Brit Plexi Jump.wav
# 	00003-12-10 01C Brit Plexi Jump.wav
# 	00003-12-11 01C Brit Plexi Jump.wav
# 	00003-12-12 01C Brit Plexi Jump.wav
# 	00003-12-13 01C Brit Plexi Jump.wav
# 	00003-12-14 01C Brit Plexi Jump.wav
# 00003-08 01C Brit Plexi Jump.wav
# 	00003-08-00 01C Brit Plexi Jump.wav
# 	00003-08-01 01C Brit Plexi Jump.wav
# 	00003-08-02 01C Brit Plexi Jump.wav
# 	00003-08-03 01C Brit Plexi Jump.wav
# 	00003-08-04 01C Brit Plexi Jump.wav
# 	00003-08-05 01C Brit Plexi Jump.wav
# 	00003-08-06 01C Brit Plexi Jump.wav
# 	00003-08-07 01C Brit Plexi Jump.wav
# 	00003-08-08 01C Brit Plexi Jump.wav
# 	00003-08-09 01C Brit Plexi Jump.wav
# 	00003-08-10 01C Brit Plexi Jump.wav
# 	00003-08-11 01C Brit Plexi Jump.wav
# 	00003-08-12 01C Brit Plexi Jump.wav
# 	00003-08-13 01C Brit Plexi Jump.wav
# 00003-01 01C Brit Plexi Jump.wav
# 	00003-01-00 01C Brit Plexi Jump.wav
# 	00003-01-01 01C Brit Plexi Jump.wav
# 	00003-01-02 01C Brit Plexi Jump.wav
# 	00003-01-03 01C Brit Plexi Jump.wav
# 	00003-01-04 01C Brit Plexi Jump.wav
# 	00003-01-05 01C Brit Plexi Jump.wav
# 	00003-01-06 01C Brit Plexi Jump.wav
# 	00003-01-07 01C Brit Plexi Jump.wav
# 	00003-01-08 01C Brit Plexi Jump.wav
# 	00003-01-09 01C Brit Plexi Jump.wav
# 	00003-01-10 01C Brit Plexi Jump.wav
# 	00003-01-11 01C Brit Plexi Jump.wav
# 	00003-01-12 01C Brit Plexi Jump.wav
# 00003-07 01C Brit Plexi Jump.wav
# 	00003-07-00 01C Brit Plexi Jump.wav
# 	00003-07-01 01C Brit Plexi Jump.wav
# 	00003-07-02 01C Brit Plexi Jump.wav
# 	00003-07-03 01C Brit Plexi Jump.wav
# 	00003-07-04 01C Brit Plexi Jump.wav
# 	00003-07-05 01C Brit Plexi Jump.wav
# 	00003-07-06 01C Brit Plexi Jump.wav
# 	00003-07-07 01C Brit Plexi Jump.wav
# 	00003-07-08 01C Brit Plexi Jump.wav
# 	00003-07-09 01C Brit Plexi Jump.wav
# 	00003-07-10 01C Brit Plexi Jump.wav
# 00003-03 01C Brit Plexi Jump.wav
# 	00003-03-00 01C Brit Plexi Jump.wav
# 	00003-03-01 01C Brit Plexi Jump.wav
# 	00003-03-02 01C Brit Plexi Jump.wav
# 	00003-03-03 01C Brit Plexi Jump.wav
# 	00003-03-04 01C Brit Plexi Jump.wav
# 	00003-03-05 01C Brit Plexi Jump.wav
# 	00003-03-06 01C Brit Plexi Jump.wav
# 	00003-03-07 01C Brit Plexi Jump.wav
# 	00003-03-08 01C Brit Plexi Jump.wav
# 	00003-03-09 01C Brit Plexi Jump.wav
# 	00003-03-10 01C Brit Plexi Jump.wav
# 	00003-03-11 01C Brit Plexi Jump.wav
# 	00003-03-12 01C Brit Plexi Jump.wav
# 00003-02 01C Brit Plexi Jump.wav
# 	00003-02-00 01C Brit Plexi Jump.wav
# 	00003-02-01 01C Brit Plexi Jump.wav
# 	00003-02-02 01C Brit Plexi Jump.wav
# 	00003-02-03 01C Brit Plexi Jump.wav
# 	00003-02-04 01C Brit Plexi Jump.wav
# 	00003-02-05 01C Brit Plexi Jump.wav
# 	00003-02-06 01C Brit Plexi Jump.wav
# 	00003-02-07 01C Brit Plexi Jump.wav
# 	00003-02-08 01C Brit Plexi Jump.wav
# 	00003-02-09 01C Brit Plexi Jump.wav
# 	00003-02-10 01C Brit Plexi Jump.wav
# 	00003-02-11 01C Brit Plexi Jump.wav
# 00003-04 01C Brit Plexi Jump.wav
# 	00003-04-00 01C Brit Plexi Jump.wav
# 	00003-04-01 01C Brit Plexi Jump.wav
# 	00003-04-02 01C Brit Plexi Jump.wav
# 	00003-04-03 01C Brit Plexi Jump.wav
# 	00003-04-04 01C Brit Plexi Jump.wav
# 	00003-04-05 01C Brit Plexi Jump.wav
# 	00003-04-06 01C Brit Plexi Jump.wav
# 	00003-04-07 01C Brit Plexi Jump.wav
# 	00003-04-08 01C Brit Plexi Jump.wav
# 	00003-04-09 01C Brit Plexi Jump.wav
# 	00003-04-10 01C Brit Plexi Jump.wav
# 00004-04 01D Cali Rectifire.wav
# 	00004-04-00 01D Cali Rectifire.wav
# 	00004-04-01 01D Cali Rectifire.wav
# 	00004-04-02 01D Cali Rectifire.wav
# 	00004-04-03 01D Cali Rectifire.wav
# 	00004-04-04 01D Cali Rectifire.wav
# 	00004-04-05 01D Cali Rectifire.wav
# 	00004-04-06 01D Cali Rectifire.wav
# 	00004-04-07 01D Cali Rectifire.wav
# 	00004-04-08 01D Cali Rectifire.wav
# 	00004-04-09 01D Cali Rectifire.wav
# 	00004-04-10 01D Cali Rectifire.wav
# 00004-12 01D Cali Rectifire.wav
# 	00004-12-00 01D Cali Rectifire.wav
# 	00004-12-01 01D Cali Rectifire.wav
# 	00004-12-02 01D Cali Rectifire.wav
# 	00004-12-03 01D Cali Rectifire.wav
# 	00004-12-04 01D Cali Rectifire.wav
# 	00004-12-05 01D Cali Rectifire.wav
# 	00004-12-06 01D Cali Rectifire.wav
# 	00004-12-07 01D Cali Rectifire.wav
# 	00004-12-08 01D Cali Rectifire.wav
# 	00004-12-09 01D Cali Rectifire.wav
# 	00004-12-10 01D Cali Rectifire.wav
# 	00004-12-11 01D Cali Rectifire.wav
# 	00004-12-12 01D Cali Rectifire.wav
# 	00004-12-13 01D Cali Rectifire.wav
# 	00004-12-14 01D Cali Rectifire.wav
# 00004-07 01D Cali Rectifire.wav
# 	00004-07-00 01D Cali Rectifire.wav
# 	00004-07-01 01D Cali Rectifire.wav
# 	00004-07-02 01D Cali Rectifire.wav
# 	00004-07-03 01D Cali Rectifire.wav
# 	00004-07-04 01D Cali Rectifire.wav
# 	00004-07-05 01D Cali Rectifire.wav
# 	00004-07-06 01D Cali Rectifire.wav
# 	00004-07-07 01D Cali Rectifire.wav
# 	00004-07-08 01D Cali Rectifire.wav
# 	00004-07-09 01D Cali Rectifire.wav
# 	00004-07-10 01D Cali Rectifire.wav
# 00004-06 01D Cali Rectifire.wav
# 	00004-06-00 01D Cali Rectifire.wav
# 	00004-06-01 01D Cali Rectifire.wav
# 	00004-06-02 01D Cali Rectifire.wav
# 	00004-06-03 01D Cali Rectifire.wav
# 	00004-06-04 01D Cali Rectifire.wav
# 	00004-06-05 01D Cali Rectifire.wav
# 	00004-06-06 01D Cali Rectifire.wav
# 	00004-06-07 01D Cali Rectifire.wav
# 	00004-06-08 01D Cali Rectifire.wav
# 	00004-06-09 01D Cali Rectifire.wav
# 	00004-06-10 01D Cali Rectifire.wav
# 	00004-06-11 01D Cali Rectifire.wav
# 	00004-06-12 01D Cali Rectifire.wav
# 	00004-06-13 01D Cali Rectifire.wav
# 00004-11 01D Cali Rectifire.wav
# 	00004-11-00 01D Cali Rectifire.wav
# 	00004-11-01 01D Cali Rectifire.wav
# 	00004-11-02 01D Cali Rectifire.wav
# 	00004-11-03 01D Cali Rectifire.wav
# 	00004-11-04 01D Cali Rectifire.wav
# 	00004-11-05 01D Cali Rectifire.wav
# 	00004-11-06 01D Cali Rectifire.wav
# 	00004-11-07 01D Cali Rectifire.wav
# 	00004-11-08 01D Cali Rectifire.wav
# 00004-03 01D Cali Rectifire.wav
# 	00004-03-00 01D Cali Rectifire.wav
# 	00004-03-01 01D Cali Rectifire.wav
# 	00004-03-02 01D Cali Rectifire.wav
# 	00004-03-03 01D Cali Rectifire.wav
# 	00004-03-04 01D Cali Rectifire.wav
# 	00004-03-05 01D Cali Rectifire.wav
# 	00004-03-06 01D Cali Rectifire.wav
# 	00004-03-07 01D Cali Rectifire.wav
# 	00004-03-08 01D Cali Rectifire.wav
# 	00004-03-09 01D Cali Rectifire.wav
# 	00004-03-10 01D Cali Rectifire.wav
# 	00004-03-11 01D Cali Rectifire.wav
# 	00004-03-12 01D Cali Rectifire.wav
# 00004-10 01D Cali Rectifire.wav
# 	00004-10-00 01D Cali Rectifire.wav
# 	00004-10-01 01D Cali Rectifire.wav
# 	00004-10-02 01D Cali Rectifire.wav
# 	00004-10-03 01D Cali Rectifire.wav
# 	00004-10-04 01D Cali Rectifire.wav
# 	00004-10-05 01D Cali Rectifire.wav
# 	00004-10-06 01D Cali Rectifire.wav
# 	00004-10-07 01D Cali Rectifire.wav
# 00004-02 01D Cali Rectifire.wav
# 	00004-02-00 01D Cali Rectifire.wav
# 	00004-02-01 01D Cali Rectifire.wav
# 	00004-02-02 01D Cali Rectifire.wav
# 	00004-02-03 01D Cali Rectifire.wav
# 	00004-02-04 01D Cali Rectifire.wav
# 	00004-02-05 01D Cali Rectifire.wav
# 	00004-02-06 01D Cali Rectifire.wav
# 	00004-02-07 01D Cali Rectifire.wav
# 	00004-02-08 01D Cali Rectifire.wav
# 	00004-02-09 01D Cali Rectifire.wav
# 	00004-02-10 01D Cali Rectifire.wav
# 	00004-02-11 01D Cali Rectifire.wav
# 00004-08 01D Cali Rectifire.wav
# 	00004-08-00 01D Cali Rectifire.wav
# 	00004-08-01 01D Cali Rectifire.wav
# 	00004-08-02 01D Cali Rectifire.wav
# 	00004-08-03 01D Cali Rectifire.wav
# 	00004-08-04 01D Cali Rectifire.wav
# 	00004-08-05 01D Cali Rectifire.wav
# 	00004-08-06 01D Cali Rectifire.wav
# 	00004-08-07 01D Cali Rectifire.wav
# 	00004-08-08 01D Cali Rectifire.wav
# 	00004-08-09 01D Cali Rectifire.wav
# 	00004-08-10 01D Cali Rectifire.wav
# 	00004-08-11 01D Cali Rectifire.wav
# 	00004-08-12 01D Cali Rectifire.wav
# 	00004-08-13 01D Cali Rectifire.wav
# 00004-05 01D Cali Rectifire.wav
# 	00004-05-00 01D Cali Rectifire.wav
# 	00004-05-01 01D Cali Rectifire.wav
# 	00004-05-02 01D Cali Rectifire.wav
# 	00004-05-03 01D Cali Rectifire.wav
# 	00004-05-04 01D Cali Rectifire.wav
# 	00004-05-05 01D Cali Rectifire.wav
# 	00004-05-06 01D Cali Rectifire.wav
# 	00004-05-07 01D Cali Rectifire.wav
# 	00004-05-08 01D Cali Rectifire.wav
# 	00004-05-09 01D Cali Rectifire.wav
# 	00004-05-10 01D Cali Rectifire.wav
# 00004-09 01D Cali Rectifire.wav
# 	00004-09-00 01D Cali Rectifire.wav
# 	00004-09-01 01D Cali Rectifire.wav
# 	00004-09-02 01D Cali Rectifire.wav
# 	00004-09-03 01D Cali Rectifire.wav
# 	00004-09-04 01D Cali Rectifire.wav
# 	00004-09-05 01D Cali Rectifire.wav
# 	00004-09-06 01D Cali Rectifire.wav
# 	00004-09-07 01D Cali Rectifire.wav
# 	00004-09-08 01D Cali Rectifire.wav
# 	00004-09-09 01D Cali Rectifire.wav
# 	00004-09-10 01D Cali Rectifire.wav
# 00004-01 01D Cali Rectifire.wav
# 	00004-01-00 01D Cali Rectifire.wav
# 	00004-01-01 01D Cali Rectifire.wav
# 	00004-01-02 01D Cali Rectifire.wav
# 	00004-01-03 01D Cali Rectifire.wav
# 	00004-01-04 01D Cali Rectifire.wav
# 	00004-01-05 01D Cali Rectifire.wav
# 	00004-01-06 01D Cali Rectifire.wav
# 	00004-01-07 01D Cali Rectifire.wav
# 	00004-01-08 01D Cali Rectifire.wav
# 	00004-01-09 01D Cali Rectifire.wav
# 	00004-01-10 01D Cali Rectifire.wav
# 	00004-01-11 01D Cali Rectifire.wav
# 	00004-01-12 01D Cali Rectifire.wav
# 00005-12 02A US Deluxe Nrm.wav
# 	00005-12-00 02A US Deluxe Nrm.wav
# 	00005-12-01 02A US Deluxe Nrm.wav
# 	00005-12-02 02A US Deluxe Nrm.wav
# 	00005-12-03 02A US Deluxe Nrm.wav
# 	00005-12-04 02A US Deluxe Nrm.wav
# 	00005-12-05 02A US Deluxe Nrm.wav
# 	00005-12-06 02A US Deluxe Nrm.wav
# 	00005-12-07 02A US Deluxe Nrm.wav
# 	00005-12-08 02A US Deluxe Nrm.wav
# 	00005-12-09 02A US Deluxe Nrm.wav
# 	00005-12-10 02A US Deluxe Nrm.wav
# 	00005-12-11 02A US Deluxe Nrm.wav
# 	00005-12-12 02A US Deluxe Nrm.wav
# 	00005-12-13 02A US Deluxe Nrm.wav
# 	00005-12-14 02A US Deluxe Nrm.wav
# 00005-01 02A US Deluxe Nrm.wav
# 	00005-01-00 02A US Deluxe Nrm.wav
# 	00005-01-01 02A US Deluxe Nrm.wav
# 	00005-01-02 02A US Deluxe Nrm.wav
# 	00005-01-03 02A US Deluxe Nrm.wav
# 	00005-01-04 02A US Deluxe Nrm.wav
# 	00005-01-05 02A US Deluxe Nrm.wav
# 	00005-01-06 02A US Deluxe Nrm.wav
# 	00005-01-07 02A US Deluxe Nrm.wav
# 	00005-01-08 02A US Deluxe Nrm.wav
# 	00005-01-09 02A US Deluxe Nrm.wav
# 	00005-01-10 02A US Deluxe Nrm.wav
# 	00005-01-11 02A US Deluxe Nrm.wav
# 	00005-01-12 02A US Deluxe Nrm.wav
# 00005-07 02A US Deluxe Nrm.wav
# 	00005-07-00 02A US Deluxe Nrm.wav
# 	00005-07-01 02A US Deluxe Nrm.wav
# 	00005-07-02 02A US Deluxe Nrm.wav
# 	00005-07-03 02A US Deluxe Nrm.wav
# 	00005-07-04 02A US Deluxe Nrm.wav
# 	00005-07-05 02A US Deluxe Nrm.wav
# 	00005-07-06 02A US Deluxe Nrm.wav
# 	00005-07-07 02A US Deluxe Nrm.wav
# 	00005-07-08 02A US Deluxe Nrm.wav
# 	00005-07-09 02A US Deluxe Nrm.wav
# 	00005-07-10 02A US Deluxe Nrm.wav
# 00005-06 02A US Deluxe Nrm.wav
# 	00005-06-00 02A US Deluxe Nrm.wav
# 	00005-06-01 02A US Deluxe Nrm.wav
# 	00005-06-02 02A US Deluxe Nrm.wav
# 	00005-06-03 02A US Deluxe Nrm.wav
# 	00005-06-04 02A US Deluxe Nrm.wav
# 	00005-06-05 02A US Deluxe Nrm.wav
# 	00005-06-06 02A US Deluxe Nrm.wav
# 	00005-06-07 02A US Deluxe Nrm.wav
# 	00005-06-08 02A US Deluxe Nrm.wav
# 	00005-06-09 02A US Deluxe Nrm.wav
# 	00005-06-10 02A US Deluxe Nrm.wav
# 	00005-06-11 02A US Deluxe Nrm.wav
# 	00005-06-12 02A US Deluxe Nrm.wav
# 	00005-06-13 02A US Deluxe Nrm.wav
# 00005-08 02A US Deluxe Nrm.wav
# 	00005-08-00 02A US Deluxe Nrm.wav
# 	00005-08-01 02A US Deluxe Nrm.wav
# 	00005-08-02 02A US Deluxe Nrm.wav
# 	00005-08-03 02A US Deluxe Nrm.wav
# 	00005-08-04 02A US Deluxe Nrm.wav
# 	00005-08-05 02A US Deluxe Nrm.wav
# 	00005-08-06 02A US Deluxe Nrm.wav
# 	00005-08-07 02A US Deluxe Nrm.wav
# 	00005-08-08 02A US Deluxe Nrm.wav
# 	00005-08-09 02A US Deluxe Nrm.wav
# 	00005-08-10 02A US Deluxe Nrm.wav
# 	00005-08-11 02A US Deluxe Nrm.wav
# 	00005-08-12 02A US Deluxe Nrm.wav
# 	00005-08-13 02A US Deluxe Nrm.wav
# 00005-11 02A US Deluxe Nrm.wav
# 	00005-11-00 02A US Deluxe Nrm.wav
# 	00005-11-01 02A US Deluxe Nrm.wav
# 	00005-11-02 02A US Deluxe Nrm.wav
# 	00005-11-03 02A US Deluxe Nrm.wav
# 	00005-11-04 02A US Deluxe Nrm.wav
# 	00005-11-05 02A US Deluxe Nrm.wav
# 	00005-11-06 02A US Deluxe Nrm.wav
# 	00005-11-07 02A US Deluxe Nrm.wav
# 	00005-11-08 02A US Deluxe Nrm.wav
# 00005-04 02A US Deluxe Nrm.wav
# 	00005-04-00 02A US Deluxe Nrm.wav
# 	00005-04-01 02A US Deluxe Nrm.wav
# 	00005-04-02 02A US Deluxe Nrm.wav
# 	00005-04-03 02A US Deluxe Nrm.wav
# 	00005-04-04 02A US Deluxe Nrm.wav
# 	00005-04-05 02A US Deluxe Nrm.wav
# 	00005-04-06 02A US Deluxe Nrm.wav
# 	00005-04-07 02A US Deluxe Nrm.wav
# 	00005-04-08 02A US Deluxe Nrm.wav
# 	00005-04-09 02A US Deluxe Nrm.wav
# 	00005-04-10 02A US Deluxe Nrm.wav
# 00005-03 02A US Deluxe Nrm.wav
# 	00005-03-00 02A US Deluxe Nrm.wav
# 	00005-03-01 02A US Deluxe Nrm.wav
# 	00005-03-02 02A US Deluxe Nrm.wav
# 	00005-03-03 02A US Deluxe Nrm.wav
# 	00005-03-04 02A US Deluxe Nrm.wav
# 	00005-03-05 02A US Deluxe Nrm.wav
# 	00005-03-06 02A US Deluxe Nrm.wav
# 	00005-03-07 02A US Deluxe Nrm.wav
# 	00005-03-08 02A US Deluxe Nrm.wav
# 	00005-03-09 02A US Deluxe Nrm.wav
# 	00005-03-10 02A US Deluxe Nrm.wav
# 	00005-03-11 02A US Deluxe Nrm.wav
# 	00005-03-12 02A US Deluxe Nrm.wav
# 00005-09 02A US Deluxe Nrm.wav
# 	00005-09-00 02A US Deluxe Nrm.wav
# 	00005-09-01 02A US Deluxe Nrm.wav
# 	00005-09-02 02A US Deluxe Nrm.wav
# 	00005-09-03 02A US Deluxe Nrm.wav
# 	00005-09-04 02A US Deluxe Nrm.wav
# 	00005-09-05 02A US Deluxe Nrm.wav
# 	00005-09-06 02A US Deluxe Nrm.wav
# 	00005-09-07 02A US Deluxe Nrm.wav
# 	00005-09-08 02A US Deluxe Nrm.wav
# 	00005-09-09 02A US Deluxe Nrm.wav
# 	00005-09-10 02A US Deluxe Nrm.wav
# 00005-05 02A US Deluxe Nrm.wav
# 	00005-05-00 02A US Deluxe Nrm.wav
# 	00005-05-01 02A US Deluxe Nrm.wav
# 	00005-05-02 02A US Deluxe Nrm.wav
# 	00005-05-03 02A US Deluxe Nrm.wav
# 	00005-05-04 02A US Deluxe Nrm.wav
# 	00005-05-05 02A US Deluxe Nrm.wav
# 	00005-05-06 02A US Deluxe Nrm.wav
# 	00005-05-07 02A US Deluxe Nrm.wav
# 	00005-05-08 02A US Deluxe Nrm.wav
# 	00005-05-09 02A US Deluxe Nrm.wav
# 	00005-05-10 02A US Deluxe Nrm.wav
# 00005-02 02A US Deluxe Nrm.wav
# 	00005-02-00 02A US Deluxe Nrm.wav
# 	00005-02-01 02A US Deluxe Nrm.wav
# 	00005-02-02 02A US Deluxe Nrm.wav
# 	00005-02-03 02A US Deluxe Nrm.wav
# 	00005-02-04 02A US Deluxe Nrm.wav
# 	00005-02-05 02A US Deluxe Nrm.wav
# 	00005-02-06 02A US Deluxe Nrm.wav
# 	00005-02-07 02A US Deluxe Nrm.wav
# 	00005-02-08 02A US Deluxe Nrm.wav
# 	00005-02-09 02A US Deluxe Nrm.wav
# 	00005-02-10 02A US Deluxe Nrm.wav
# 	00005-02-11 02A US Deluxe Nrm.wav
# 00005-10 02A US Deluxe Nrm.wav
# 	00005-10-00 02A US Deluxe Nrm.wav
# 	00005-10-01 02A US Deluxe Nrm.wav
# 	00005-10-02 02A US Deluxe Nrm.wav
# 	00005-10-03 02A US Deluxe Nrm.wav
# 	00005-10-04 02A US Deluxe Nrm.wav
# 	00005-10-05 02A US Deluxe Nrm.wav
# 	00005-10-06 02A US Deluxe Nrm.wav
# 	00005-10-07 02A US Deluxe Nrm.wav
# 00006-07 02B A30 Fawn Nrm.wav
# 	00006-07-00 02B A30 Fawn Nrm.wav
# 	00006-07-01 02B A30 Fawn Nrm.wav
# 	00006-07-02 02B A30 Fawn Nrm.wav
# 	00006-07-03 02B A30 Fawn Nrm.wav
# 	00006-07-04 02B A30 Fawn Nrm.wav
# 	00006-07-05 02B A30 Fawn Nrm.wav
# 	00006-07-06 02B A30 Fawn Nrm.wav
# 	00006-07-07 02B A30 Fawn Nrm.wav
# 	00006-07-08 02B A30 Fawn Nrm.wav
# 	00006-07-09 02B A30 Fawn Nrm.wav
# 	00006-07-10 02B A30 Fawn Nrm.wav
# 00006-11 02B A30 Fawn Nrm.wav
# 	00006-11-00 02B A30 Fawn Nrm.wav
# 	00006-11-01 02B A30 Fawn Nrm.wav
# 	00006-11-02 02B A30 Fawn Nrm.wav
# 	00006-11-03 02B A30 Fawn Nrm.wav
# 	00006-11-04 02B A30 Fawn Nrm.wav
# 	00006-11-05 02B A30 Fawn Nrm.wav
# 	00006-11-06 02B A30 Fawn Nrm.wav
# 	00006-11-07 02B A30 Fawn Nrm.wav
# 	00006-11-08 02B A30 Fawn Nrm.wav
# 00006-06 02B A30 Fawn Nrm.wav
# 	00006-06-00 02B A30 Fawn Nrm.wav
# 	00006-06-01 02B A30 Fawn Nrm.wav
# 	00006-06-02 02B A30 Fawn Nrm.wav
# 	00006-06-03 02B A30 Fawn Nrm.wav
# 	00006-06-04 02B A30 Fawn Nrm.wav
# 	00006-06-05 02B A30 Fawn Nrm.wav
# 	00006-06-06 02B A30 Fawn Nrm.wav
# 	00006-06-07 02B A30 Fawn Nrm.wav
# 	00006-06-08 02B A30 Fawn Nrm.wav
# 	00006-06-09 02B A30 Fawn Nrm.wav
# 	00006-06-10 02B A30 Fawn Nrm.wav
# 	00006-06-11 02B A30 Fawn Nrm.wav
# 	00006-06-12 02B A30 Fawn Nrm.wav
# 	00006-06-13 02B A30 Fawn Nrm.wav
# 00006-08 02B A30 Fawn Nrm.wav
# 	00006-08-00 02B A30 Fawn Nrm.wav
# 	00006-08-01 02B A30 Fawn Nrm.wav
# 	00006-08-02 02B A30 Fawn Nrm.wav
# 	00006-08-03 02B A30 Fawn Nrm.wav
# 	00006-08-04 02B A30 Fawn Nrm.wav
# 	00006-08-05 02B A30 Fawn Nrm.wav
# 	00006-08-06 02B A30 Fawn Nrm.wav
# 	00006-08-07 02B A30 Fawn Nrm.wav
# 	00006-08-08 02B A30 Fawn Nrm.wav
# 	00006-08-09 02B A30 Fawn Nrm.wav
# 	00006-08-10 02B A30 Fawn Nrm.wav
# 	00006-08-11 02B A30 Fawn Nrm.wav
# 	00006-08-12 02B A30 Fawn Nrm.wav
# 	00006-08-13 02B A30 Fawn Nrm.wav
# 00006-10 02B A30 Fawn Nrm.wav
# 	00006-10-00 02B A30 Fawn Nrm.wav
# 	00006-10-01 02B A30 Fawn Nrm.wav
# 	00006-10-02 02B A30 Fawn Nrm.wav
# 	00006-10-03 02B A30 Fawn Nrm.wav
# 	00006-10-04 02B A30 Fawn Nrm.wav
# 	00006-10-05 02B A30 Fawn Nrm.wav
# 	00006-10-06 02B A30 Fawn Nrm.wav
# 	00006-10-07 02B A30 Fawn Nrm.wav
# 00006-01 02B A30 Fawn Nrm.wav
# 	00006-01-00 02B A30 Fawn Nrm.wav
# 	00006-01-01 02B A30 Fawn Nrm.wav
# 	00006-01-02 02B A30 Fawn Nrm.wav
# 	00006-01-03 02B A30 Fawn Nrm.wav
# 	00006-01-04 02B A30 Fawn Nrm.wav
# 	00006-01-05 02B A30 Fawn Nrm.wav
# 	00006-01-06 02B A30 Fawn Nrm.wav
# 	00006-01-07 02B A30 Fawn Nrm.wav
# 	00006-01-08 02B A30 Fawn Nrm.wav
# 	00006-01-09 02B A30 Fawn Nrm.wav
# 	00006-01-10 02B A30 Fawn Nrm.wav
# 	00006-01-11 02B A30 Fawn Nrm.wav
# 	00006-01-12 02B A30 Fawn Nrm.wav
# 00006-12 02B A30 Fawn Nrm.wav
# 	00006-12-00 02B A30 Fawn Nrm.wav
# 	00006-12-01 02B A30 Fawn Nrm.wav
# 	00006-12-02 02B A30 Fawn Nrm.wav
# 	00006-12-03 02B A30 Fawn Nrm.wav
# 	00006-12-04 02B A30 Fawn Nrm.wav
# 	00006-12-05 02B A30 Fawn Nrm.wav
# 	00006-12-06 02B A30 Fawn Nrm.wav
# 	00006-12-07 02B A30 Fawn Nrm.wav
# 	00006-12-08 02B A30 Fawn Nrm.wav
# 	00006-12-09 02B A30 Fawn Nrm.wav
# 	00006-12-10 02B A30 Fawn Nrm.wav
# 	00006-12-11 02B A30 Fawn Nrm.wav
# 	00006-12-12 02B A30 Fawn Nrm.wav
# 	00006-12-13 02B A30 Fawn Nrm.wav
# 	00006-12-14 02B A30 Fawn Nrm.wav
# 00006-09 02B A30 Fawn Nrm.wav
# 	00006-09-00 02B A30 Fawn Nrm.wav
# 	00006-09-01 02B A30 Fawn Nrm.wav
# 	00006-09-02 02B A30 Fawn Nrm.wav
# 	00006-09-03 02B A30 Fawn Nrm.wav
# 	00006-09-04 02B A30 Fawn Nrm.wav
# 	00006-09-05 02B A30 Fawn Nrm.wav
# 	00006-09-06 02B A30 Fawn Nrm.wav
# 	00006-09-07 02B A30 Fawn Nrm.wav
# 	00006-09-08 02B A30 Fawn Nrm.wav
# 	00006-09-09 02B A30 Fawn Nrm.wav
# 	00006-09-10 02B A30 Fawn Nrm.wav
# 00006-04 02B A30 Fawn Nrm.wav
# 	00006-04-00 02B A30 Fawn Nrm.wav
# 	00006-04-01 02B A30 Fawn Nrm.wav
# 	00006-04-02 02B A30 Fawn Nrm.wav
# 	00006-04-03 02B A30 Fawn Nrm.wav
# 	00006-04-04 02B A30 Fawn Nrm.wav
# 	00006-04-05 02B A30 Fawn Nrm.wav
# 	00006-04-06 02B A30 Fawn Nrm.wav
# 	00006-04-07 02B A30 Fawn Nrm.wav
# 	00006-04-08 02B A30 Fawn Nrm.wav
# 	00006-04-09 02B A30 Fawn Nrm.wav
# 	00006-04-10 02B A30 Fawn Nrm.wav
# 00006-02 02B A30 Fawn Nrm.wav
# 	00006-02-00 02B A30 Fawn Nrm.wav
# 	00006-02-01 02B A30 Fawn Nrm.wav
# 	00006-02-02 02B A30 Fawn Nrm.wav
# 	00006-02-03 02B A30 Fawn Nrm.wav
# 	00006-02-04 02B A30 Fawn Nrm.wav
# 	00006-02-05 02B A30 Fawn Nrm.wav
# 	00006-02-06 02B A30 Fawn Nrm.wav
# 	00006-02-07 02B A30 Fawn Nrm.wav
# 	00006-02-08 02B A30 Fawn Nrm.wav
# 	00006-02-09 02B A30 Fawn Nrm.wav
# 	00006-02-10 02B A30 Fawn Nrm.wav
# 	00006-02-11 02B A30 Fawn Nrm.wav
# 00006-03 02B A30 Fawn Nrm.wav
# 	00006-03-00 02B A30 Fawn Nrm.wav
# 	00006-03-01 02B A30 Fawn Nrm.wav
# 	00006-03-02 02B A30 Fawn Nrm.wav
# 	00006-03-03 02B A30 Fawn Nrm.wav
# 	00006-03-04 02B A30 Fawn Nrm.wav
# 	00006-03-05 02B A30 Fawn Nrm.wav
# 	00006-03-06 02B A30 Fawn Nrm.wav
# 	00006-03-07 02B A30 Fawn Nrm.wav
# 	00006-03-08 02B A30 Fawn Nrm.wav
# 	00006-03-09 02B A30 Fawn Nrm.wav
# 	00006-03-10 02B A30 Fawn Nrm.wav
# 	00006-03-11 02B A30 Fawn Nrm.wav
# 	00006-03-12 02B A30 Fawn Nrm.wav
# 00006-05 02B A30 Fawn Nrm.wav
# 	00006-05-00 02B A30 Fawn Nrm.wav
# 	00006-05-01 02B A30 Fawn Nrm.wav
# 	00006-05-02 02B A30 Fawn Nrm.wav
# 	00006-05-03 02B A30 Fawn Nrm.wav
# 	00006-05-04 02B A30 Fawn Nrm.wav
# 	00006-05-05 02B A30 Fawn Nrm.wav
# 	00006-05-06 02B A30 Fawn Nrm.wav
# 	00006-05-07 02B A30 Fawn Nrm.wav
# 	00006-05-08 02B A30 Fawn Nrm.wav
# 	00006-05-09 02B A30 Fawn Nrm.wav
# 	00006-05-10 02B A30 Fawn Nrm.wav
# 00007-06 02C Revv Gen Purple.wav
# 	00007-06-00 02C Revv Gen Purple.wav
# 	00007-06-01 02C Revv Gen Purple.wav
# 	00007-06-02 02C Revv Gen Purple.wav
# 	00007-06-03 02C Revv Gen Purple.wav
# 	00007-06-04 02C Revv Gen Purple.wav
# 	00007-06-05 02C Revv Gen Purple.wav
# 	00007-06-06 02C Revv Gen Purple.wav
# 	00007-06-07 02C Revv Gen Purple.wav
# 	00007-06-08 02C Revv Gen Purple.wav
# 	00007-06-09 02C Revv Gen Purple.wav
# 	00007-06-10 02C Revv Gen Purple.wav
# 	00007-06-11 02C Revv Gen Purple.wav
# 	00007-06-12 02C Revv Gen Purple.wav
# 	00007-06-13 02C Revv Gen Purple.wav
# 00007-04 02C Revv Gen Purple.wav
# 	00007-04-00 02C Revv Gen Purple.wav
# 	00007-04-01 02C Revv Gen Purple.wav
# 	00007-04-02 02C Revv Gen Purple.wav
# 	00007-04-03 02C Revv Gen Purple.wav
# 	00007-04-04 02C Revv Gen Purple.wav
# 	00007-04-05 02C Revv Gen Purple.wav
# 	00007-04-06 02C Revv Gen Purple.wav
# 	00007-04-07 02C Revv Gen Purple.wav
# 	00007-04-08 02C Revv Gen Purple.wav
# 	00007-04-09 02C Revv Gen Purple.wav
# 	00007-04-10 02C Revv Gen Purple.wav
# 00007-10 02C Revv Gen Purple.wav
# 	00007-10-00 02C Revv Gen Purple.wav
# 	00007-10-01 02C Revv Gen Purple.wav
# 	00007-10-02 02C Revv Gen Purple.wav
# 	00007-10-03 02C Revv Gen Purple.wav
# 	00007-10-04 02C Revv Gen Purple.wav
# 	00007-10-05 02C Revv Gen Purple.wav
# 	00007-10-06 02C Revv Gen Purple.wav
# 	00007-10-07 02C Revv Gen Purple.wav
# 00007-11 02C Revv Gen Purple.wav
# 	00007-11-00 02C Revv Gen Purple.wav
# 	00007-11-01 02C Revv Gen Purple.wav
# 	00007-11-02 02C Revv Gen Purple.wav
# 	00007-11-03 02C Revv Gen Purple.wav
# 	00007-11-04 02C Revv Gen Purple.wav
# 	00007-11-05 02C Revv Gen Purple.wav
# 	00007-11-06 02C Revv Gen Purple.wav
# 	00007-11-07 02C Revv Gen Purple.wav
# 	00007-11-08 02C Revv Gen Purple.wav
# 00007-08 02C Revv Gen Purple.wav
# 	00007-08-00 02C Revv Gen Purple.wav
# 	00007-08-01 02C Revv Gen Purple.wav
# 	00007-08-02 02C Revv Gen Purple.wav
# 	00007-08-03 02C Revv Gen Purple.wav
# 	00007-08-04 02C Revv Gen Purple.wav
# 	00007-08-05 02C Revv Gen Purple.wav
# 	00007-08-06 02C Revv Gen Purple.wav
# 	00007-08-07 02C Revv Gen Purple.wav
# 	00007-08-08 02C Revv Gen Purple.wav
# 	00007-08-09 02C Revv Gen Purple.wav
# 	00007-08-10 02C Revv Gen Purple.wav
# 	00007-08-11 02C Revv Gen Purple.wav
# 	00007-08-12 02C Revv Gen Purple.wav
# 	00007-08-13 02C Revv Gen Purple.wav
# 00007-01 02C Revv Gen Purple.wav
# 	00007-01-00 02C Revv Gen Purple.wav
# 	00007-01-01 02C Revv Gen Purple.wav
# 	00007-01-02 02C Revv Gen Purple.wav
# 	00007-01-03 02C Revv Gen Purple.wav
# 	00007-01-04 02C Revv Gen Purple.wav
# 	00007-01-05 02C Revv Gen Purple.wav
# 	00007-01-06 02C Revv Gen Purple.wav
# 	00007-01-07 02C Revv Gen Purple.wav
# 	00007-01-08 02C Revv Gen Purple.wav
# 	00007-01-09 02C Revv Gen Purple.wav
# 	00007-01-10 02C Revv Gen Purple.wav
# 	00007-01-11 02C Revv Gen Purple.wav
# 	00007-01-12 02C Revv Gen Purple.wav
# 00007-05 02C Revv Gen Purple.wav
# 	00007-05-00 02C Revv Gen Purple.wav
# 	00007-05-01 02C Revv Gen Purple.wav
# 	00007-05-02 02C Revv Gen Purple.wav
# 	00007-05-03 02C Revv Gen Purple.wav
# 	00007-05-04 02C Revv Gen Purple.wav
# 	00007-05-05 02C Revv Gen Purple.wav
# 	00007-05-06 02C Revv Gen Purple.wav
# 	00007-05-07 02C Revv Gen Purple.wav
# 	00007-05-08 02C Revv Gen Purple.wav
# 	00007-05-09 02C Revv Gen Purple.wav
# 	00007-05-10 02C Revv Gen Purple.wav
# 00007-07 02C Revv Gen Purple.wav
# 	00007-07-00 02C Revv Gen Purple.wav
# 	00007-07-01 02C Revv Gen Purple.wav
# 	00007-07-02 02C Revv Gen Purple.wav
# 	00007-07-03 02C Revv Gen Purple.wav
# 	00007-07-04 02C Revv Gen Purple.wav
# 	00007-07-05 02C Revv Gen Purple.wav
# 	00007-07-06 02C Revv Gen Purple.wav
# 	00007-07-07 02C Revv Gen Purple.wav
# 	00007-07-08 02C Revv Gen Purple.wav
# 	00007-07-09 02C Revv Gen Purple.wav
# 	00007-07-10 02C Revv Gen Purple.wav
# 00007-02 02C Revv Gen Purple.wav
# 	00007-02-00 02C Revv Gen Purple.wav
# 	00007-02-01 02C Revv Gen Purple.wav
# 	00007-02-02 02C Revv Gen Purple.wav
# 	00007-02-03 02C Revv Gen Purple.wav
# 	00007-02-04 02C Revv Gen Purple.wav
# 	00007-02-05 02C Revv Gen Purple.wav
# 	00007-02-06 02C Revv Gen Purple.wav
# 	00007-02-07 02C Revv Gen Purple.wav
# 	00007-02-08 02C Revv Gen Purple.wav
# 	00007-02-09 02C Revv Gen Purple.wav
# 	00007-02-10 02C Revv Gen Purple.wav
# 	00007-02-11 02C Revv Gen Purple.wav
# 00007-09 02C Revv Gen Purple.wav
# 	00007-09-00 02C Revv Gen Purple.wav
# 	00007-09-01 02C Revv Gen Purple.wav
# 	00007-09-02 02C Revv Gen Purple.wav
# 	00007-09-03 02C Revv Gen Purple.wav
# 	00007-09-04 02C Revv Gen Purple.wav
# 	00007-09-05 02C Revv Gen Purple.wav
# 	00007-09-06 02C Revv Gen Purple.wav
# 	00007-09-07 02C Revv Gen Purple.wav
# 	00007-09-08 02C Revv Gen Purple.wav
# 	00007-09-09 02C Revv Gen Purple.wav
# 	00007-09-10 02C Revv Gen Purple.wav
# 00007-12 02C Revv Gen Purple.wav
# 	00007-12-00 02C Revv Gen Purple.wav
# 	00007-12-01 02C Revv Gen Purple.wav
# 	00007-12-02 02C Revv Gen Purple.wav
# 	00007-12-03 02C Revv Gen Purple.wav
# 	00007-12-04 02C Revv Gen Purple.wav
# 	00007-12-05 02C Revv Gen Purple.wav
# 	00007-12-06 02C Revv Gen Purple.wav
# 	00007-12-07 02C Revv Gen Purple.wav
# 	00007-12-08 02C Revv Gen Purple.wav
# 	00007-12-09 02C Revv Gen Purple.wav
# 	00007-12-10 02C Revv Gen Purple.wav
# 	00007-12-11 02C Revv Gen Purple.wav
# 	00007-12-12 02C Revv Gen Purple.wav
# 	00007-12-13 02C Revv Gen Purple.wav
# 	00007-12-14 02C Revv Gen Purple.wav
# 00007-03 02C Revv Gen Purple.wav
# 	00007-03-00 02C Revv Gen Purple.wav
# 	00007-03-01 02C Revv Gen Purple.wav
# 	00007-03-02 02C Revv Gen Purple.wav
# 	00007-03-03 02C Revv Gen Purple.wav
# 	00007-03-04 02C Revv Gen Purple.wav
# 	00007-03-05 02C Revv Gen Purple.wav
# 	00007-03-06 02C Revv Gen Purple.wav
# 	00007-03-07 02C Revv Gen Purple.wav
# 	00007-03-08 02C Revv Gen Purple.wav
# 	00007-03-09 02C Revv Gen Purple.wav
# 	00007-03-10 02C Revv Gen Purple.wav
# 	00007-03-11 02C Revv Gen Purple.wav
# 	00007-03-12 02C Revv Gen Purple.wav
# 00008-11 02D Revv Gen Red.wav
# 	00008-11-00 02D Revv Gen Red.wav
# 	00008-11-01 02D Revv Gen Red.wav
# 	00008-11-02 02D Revv Gen Red.wav
# 	00008-11-03 02D Revv Gen Red.wav
# 	00008-11-04 02D Revv Gen Red.wav
# 	00008-11-05 02D Revv Gen Red.wav
# 	00008-11-06 02D Revv Gen Red.wav
# 	00008-11-07 02D Revv Gen Red.wav
# 	00008-11-08 02D Revv Gen Red.wav
# 00008-10 02D Revv Gen Red.wav
# 	00008-10-00 02D Revv Gen Red.wav
# 	00008-10-01 02D Revv Gen Red.wav
# 	00008-10-02 02D Revv Gen Red.wav
# 	00008-10-03 02D Revv Gen Red.wav
# 	00008-10-04 02D Revv Gen Red.wav
# 	00008-10-05 02D Revv Gen Red.wav
# 	00008-10-06 02D Revv Gen Red.wav
# 	00008-10-07 02D Revv Gen Red.wav
# 00008-09 02D Revv Gen Red.wav
# 	00008-09-00 02D Revv Gen Red.wav
# 	00008-09-01 02D Revv Gen Red.wav
# 	00008-09-02 02D Revv Gen Red.wav
# 	00008-09-03 02D Revv Gen Red.wav
# 	00008-09-04 02D Revv Gen Red.wav
# 	00008-09-05 02D Revv Gen Red.wav
# 	00008-09-06 02D Revv Gen Red.wav
# 	00008-09-07 02D Revv Gen Red.wav
# 	00008-09-08 02D Revv Gen Red.wav
# 	00008-09-09 02D Revv Gen Red.wav
# 	00008-09-10 02D Revv Gen Red.wav
# 00008-05 02D Revv Gen Red.wav
# 	00008-05-00 02D Revv Gen Red.wav
# 	00008-05-01 02D Revv Gen Red.wav
# 	00008-05-02 02D Revv Gen Red.wav
# 	00008-05-03 02D Revv Gen Red.wav
# 	00008-05-04 02D Revv Gen Red.wav
# 	00008-05-05 02D Revv Gen Red.wav
# 	00008-05-06 02D Revv Gen Red.wav
# 	00008-05-07 02D Revv Gen Red.wav
# 	00008-05-08 02D Revv Gen Red.wav
# 	00008-05-09 02D Revv Gen Red.wav
# 	00008-05-10 02D Revv Gen Red.wav
# 00008-01 02D Revv Gen Red.wav
# 	00008-01-00 02D Revv Gen Red.wav
# 	00008-01-01 02D Revv Gen Red.wav
# 	00008-01-02 02D Revv Gen Red.wav
# 	00008-01-03 02D Revv Gen Red.wav
# 	00008-01-04 02D Revv Gen Red.wav
# 	00008-01-05 02D Revv Gen Red.wav
# 	00008-01-06 02D Revv Gen Red.wav
# 	00008-01-07 02D Revv Gen Red.wav
# 	00008-01-08 02D Revv Gen Red.wav
# 	00008-01-09 02D Revv Gen Red.wav
# 	00008-01-10 02D Revv Gen Red.wav
# 	00008-01-11 02D Revv Gen Red.wav
# 	00008-01-12 02D Revv Gen Red.wav
# 00008-12 02D Revv Gen Red.wav
# 	00008-12-00 02D Revv Gen Red.wav
# 	00008-12-01 02D Revv Gen Red.wav
# 	00008-12-02 02D Revv Gen Red.wav
# 	00008-12-03 02D Revv Gen Red.wav
# 	00008-12-04 02D Revv Gen Red.wav
# 	00008-12-05 02D Revv Gen Red.wav
# 	00008-12-06 02D Revv Gen Red.wav
# 	00008-12-07 02D Revv Gen Red.wav
# 	00008-12-08 02D Revv Gen Red.wav
# 	00008-12-09 02D Revv Gen Red.wav
# 	00008-12-10 02D Revv Gen Red.wav
# 	00008-12-11 02D Revv Gen Red.wav
# 	00008-12-12 02D Revv Gen Red.wav
# 	00008-12-13 02D Revv Gen Red.wav
# 	00008-12-14 02D Revv Gen Red.wav
# 00008-08 02D Revv Gen Red.wav
# 	00008-08-00 02D Revv Gen Red.wav
# 	00008-08-01 02D Revv Gen Red.wav
# 	00008-08-02 02D Revv Gen Red.wav
# 	00008-08-03 02D Revv Gen Red.wav
# 	00008-08-04 02D Revv Gen Red.wav
# 	00008-08-05 02D Revv Gen Red.wav
# 	00008-08-06 02D Revv Gen Red.wav
# 	00008-08-07 02D Revv Gen Red.wav
# 	00008-08-08 02D Revv Gen Red.wav
# 	00008-08-09 02D Revv Gen Red.wav
# 	00008-08-10 02D Revv Gen Red.wav
# 	00008-08-11 02D Revv Gen Red.wav
# 	00008-08-12 02D Revv Gen Red.wav
# 	00008-08-13 02D Revv Gen Red.wav
# 00008-03 02D Revv Gen Red.wav
# 	00008-03-00 02D Revv Gen Red.wav
# 	00008-03-01 02D Revv Gen Red.wav
# 	00008-03-02 02D Revv Gen Red.wav
# 	00008-03-03 02D Revv Gen Red.wav
# 	00008-03-04 02D Revv Gen Red.wav
# 	00008-03-05 02D Revv Gen Red.wav
# 	00008-03-06 02D Revv Gen Red.wav
# 	00008-03-07 02D Revv Gen Red.wav
# 	00008-03-08 02D Revv Gen Red.wav
# 	00008-03-09 02D Revv Gen Red.wav
# 	00008-03-10 02D Revv Gen Red.wav
# 	00008-03-11 02D Revv Gen Red.wav
# 	00008-03-12 02D Revv Gen Red.wav
# 00008-07 02D Revv Gen Red.wav
# 	00008-07-00 02D Revv Gen Red.wav
# 	00008-07-01 02D Revv Gen Red.wav
# 	00008-07-02 02D Revv Gen Red.wav
# 	00008-07-03 02D Revv Gen Red.wav
# 	00008-07-04 02D Revv Gen Red.wav
# 	00008-07-05 02D Revv Gen Red.wav
# 	00008-07-06 02D Revv Gen Red.wav
# 	00008-07-07 02D Revv Gen Red.wav
# 	00008-07-08 02D Revv Gen Red.wav
# 	00008-07-09 02D Revv Gen Red.wav
# 	00008-07-10 02D Revv Gen Red.wav
# 00008-06 02D Revv Gen Red.wav
# 	00008-06-00 02D Revv Gen Red.wav
# 	00008-06-01 02D Revv Gen Red.wav
# 	00008-06-02 02D Revv Gen Red.wav
# 	00008-06-03 02D Revv Gen Red.wav
# 	00008-06-04 02D Revv Gen Red.wav
# 	00008-06-05 02D Revv Gen Red.wav
# 	00008-06-06 02D Revv Gen Red.wav
# 	00008-06-07 02D Revv Gen Red.wav
# 	00008-06-08 02D Revv Gen Red.wav
# 	00008-06-09 02D Revv Gen Red.wav
# 	00008-06-10 02D Revv Gen Red.wav
# 	00008-06-11 02D Revv Gen Red.wav
# 	00008-06-12 02D Revv Gen Red.wav
# 	00008-06-13 02D Revv Gen Red.wav
# 00008-02 02D Revv Gen Red.wav
# 	00008-02-00 02D Revv Gen Red.wav
# 	00008-02-01 02D Revv Gen Red.wav
# 	00008-02-02 02D Revv Gen Red.wav
# 	00008-02-03 02D Revv Gen Red.wav
# 	00008-02-04 02D Revv Gen Red.wav
# 	00008-02-05 02D Revv Gen Red.wav
# 	00008-02-06 02D Revv Gen Red.wav
# 	00008-02-07 02D Revv Gen Red.wav
# 	00008-02-08 02D Revv Gen Red.wav
# 	00008-02-09 02D Revv Gen Red.wav
# 	00008-02-10 02D Revv Gen Red.wav
# 	00008-02-11 02D Revv Gen Red.wav
# 00008-04 02D Revv Gen Red.wav
# 	00008-04-00 02D Revv Gen Red.wav
# 	00008-04-01 02D Revv Gen Red.wav
# 	00008-04-02 02D Revv Gen Red.wav
# 	00008-04-03 02D Revv Gen Red.wav
# 	00008-04-04 02D Revv Gen Red.wav
# 	00008-04-05 02D Revv Gen Red.wav
# 	00008-04-06 02D Revv Gen Red.wav
# 	00008-04-07 02D Revv Gen Red.wav
# 	00008-04-08 02D Revv Gen Red.wav
# 	00008-04-09 02D Revv Gen Red.wav
# 	00008-04-10 02D Revv Gen Red.wav
# 00009-06 03A Archetype Clean.wav
# 	00009-06-00 03A Archetype Clean.wav
# 	00009-06-01 03A Archetype Clean.wav
# 	00009-06-02 03A Archetype Clean.wav
# 	00009-06-03 03A Archetype Clean.wav
# 	00009-06-04 03A Archetype Clean.wav
# 	00009-06-05 03A Archetype Clean.wav
# 	00009-06-06 03A Archetype Clean.wav
# 	00009-06-07 03A Archetype Clean.wav
# 	00009-06-08 03A Archetype Clean.wav
# 	00009-06-09 03A Archetype Clean.wav
# 	00009-06-10 03A Archetype Clean.wav
# 	00009-06-11 03A Archetype Clean.wav
# 	00009-06-12 03A Archetype Clean.wav
# 	00009-06-13 03A Archetype Clean.wav
# 00009-12 03A Archetype Clean.wav
# 	00009-12-00 03A Archetype Clean.wav
# 	00009-12-01 03A Archetype Clean.wav
# 	00009-12-02 03A Archetype Clean.wav
# 	00009-12-03 03A Archetype Clean.wav
# 	00009-12-04 03A Archetype Clean.wav
# 	00009-12-05 03A Archetype Clean.wav
# 	00009-12-06 03A Archetype Clean.wav
# 	00009-12-07 03A Archetype Clean.wav
# 	00009-12-08 03A Archetype Clean.wav
# 	00009-12-09 03A Archetype Clean.wav
# 	00009-12-10 03A Archetype Clean.wav
# 	00009-12-11 03A Archetype Clean.wav
# 	00009-12-12 03A Archetype Clean.wav
# 	00009-12-13 03A Archetype Clean.wav
# 	00009-12-14 03A Archetype Clean.wav
# 00009-07 03A Archetype Clean.wav
# 	00009-07-00 03A Archetype Clean.wav
# 	00009-07-01 03A Archetype Clean.wav
# 	00009-07-02 03A Archetype Clean.wav
# 	00009-07-03 03A Archetype Clean.wav
# 	00009-07-04 03A Archetype Clean.wav
# 	00009-07-05 03A Archetype Clean.wav
# 	00009-07-06 03A Archetype Clean.wav
# 	00009-07-07 03A Archetype Clean.wav
# 	00009-07-08 03A Archetype Clean.wav
# 	00009-07-09 03A Archetype Clean.wav
# 	00009-07-10 03A Archetype Clean.wav
# 00009-09 03A Archetype Clean.wav
# 	00009-09-00 03A Archetype Clean.wav
# 	00009-09-01 03A Archetype Clean.wav
# 	00009-09-02 03A Archetype Clean.wav
# 	00009-09-03 03A Archetype Clean.wav
# 	00009-09-04 03A Archetype Clean.wav
# 	00009-09-05 03A Archetype Clean.wav
# 	00009-09-06 03A Archetype Clean.wav
# 	00009-09-07 03A Archetype Clean.wav
# 	00009-09-08 03A Archetype Clean.wav
# 	00009-09-09 03A Archetype Clean.wav
# 	00009-09-10 03A Archetype Clean.wav
# 00009-11 03A Archetype Clean.wav
# 	00009-11-00 03A Archetype Clean.wav
# 	00009-11-01 03A Archetype Clean.wav
# 	00009-11-02 03A Archetype Clean.wav
# 	00009-11-03 03A Archetype Clean.wav
# 	00009-11-04 03A Archetype Clean.wav
# 	00009-11-05 03A Archetype Clean.wav
# 	00009-11-06 03A Archetype Clean.wav
# 	00009-11-07 03A Archetype Clean.wav
# 	00009-11-08 03A Archetype Clean.wav
# 00009-08 03A Archetype Clean.wav
# 	00009-08-00 03A Archetype Clean.wav
# 	00009-08-01 03A Archetype Clean.wav
# 	00009-08-02 03A Archetype Clean.wav
# 	00009-08-03 03A Archetype Clean.wav
# 	00009-08-04 03A Archetype Clean.wav
# 	00009-08-05 03A Archetype Clean.wav
# 	00009-08-06 03A Archetype Clean.wav
# 	00009-08-07 03A Archetype Clean.wav
# 	00009-08-08 03A Archetype Clean.wav
# 	00009-08-09 03A Archetype Clean.wav
# 	00009-08-10 03A Archetype Clean.wav
# 	00009-08-11 03A Archetype Clean.wav
# 	00009-08-12 03A Archetype Clean.wav
# 	00009-08-13 03A Archetype Clean.wav
# 00009-05 03A Archetype Clean.wav
# 	00009-05-00 03A Archetype Clean.wav
# 	00009-05-01 03A Archetype Clean.wav
# 	00009-05-02 03A Archetype Clean.wav
# 	00009-05-03 03A Archetype Clean.wav
# 	00009-05-04 03A Archetype Clean.wav
# 	00009-05-05 03A Archetype Clean.wav
# 	00009-05-06 03A Archetype Clean.wav
# 	00009-05-07 03A Archetype Clean.wav
# 	00009-05-08 03A Archetype Clean.wav
# 	00009-05-09 03A Archetype Clean.wav
# 	00009-05-10 03A Archetype Clean.wav
# 00009-02 03A Archetype Clean.wav
# 	00009-02-00 03A Archetype Clean.wav
# 	00009-02-01 03A Archetype Clean.wav
# 	00009-02-02 03A Archetype Clean.wav
# 	00009-02-03 03A Archetype Clean.wav
# 	00009-02-04 03A Archetype Clean.wav
# 	00009-02-05 03A Archetype Clean.wav
# 	00009-02-06 03A Archetype Clean.wav
# 	00009-02-07 03A Archetype Clean.wav
# 	00009-02-08 03A Archetype Clean.wav
# 	00009-02-09 03A Archetype Clean.wav
# 	00009-02-10 03A Archetype Clean.wav
# 	00009-02-11 03A Archetype Clean.wav
# 00009-04 03A Archetype Clean.wav
# 	00009-04-00 03A Archetype Clean.wav
# 	00009-04-01 03A Archetype Clean.wav
# 	00009-04-02 03A Archetype Clean.wav
# 	00009-04-03 03A Archetype Clean.wav
# 	00009-04-04 03A Archetype Clean.wav
# 	00009-04-05 03A Archetype Clean.wav
# 	00009-04-06 03A Archetype Clean.wav
# 	00009-04-07 03A Archetype Clean.wav
# 	00009-04-08 03A Archetype Clean.wav
# 	00009-04-09 03A Archetype Clean.wav
# 	00009-04-10 03A Archetype Clean.wav
# 00009-10 03A Archetype Clean.wav
# 	00009-10-00 03A Archetype Clean.wav
# 	00009-10-01 03A Archetype Clean.wav
# 	00009-10-02 03A Archetype Clean.wav
# 	00009-10-03 03A Archetype Clean.wav
# 	00009-10-04 03A Archetype Clean.wav
# 	00009-10-05 03A Archetype Clean.wav
# 	00009-10-06 03A Archetype Clean.wav
# 	00009-10-07 03A Archetype Clean.wav
# 00009-03 03A Archetype Clean.wav
# 	00009-03-00 03A Archetype Clean.wav
# 	00009-03-01 03A Archetype Clean.wav
# 	00009-03-02 03A Archetype Clean.wav
# 	00009-03-03 03A Archetype Clean.wav
# 	00009-03-04 03A Archetype Clean.wav
# 	00009-03-05 03A Archetype Clean.wav
# 	00009-03-06 03A Archetype Clean.wav
# 	00009-03-07 03A Archetype Clean.wav
# 	00009-03-08 03A Archetype Clean.wav
# 	00009-03-09 03A Archetype Clean.wav
# 	00009-03-10 03A Archetype Clean.wav
# 	00009-03-11 03A Archetype Clean.wav
# 	00009-03-12 03A Archetype Clean.wav
# 00009-01 03A Archetype Clean.wav
# 	00009-01-00 03A Archetype Clean.wav
# ...
# 	00014-04-10 04B Fullerton Brt.wav
# 00014-10 04B Fullerton Brt.wav
# 	00014-10-00 04B Fullerton Brt.wav
# 	00014-10-01 04B Fullerton Brt.wav
# 	00014-10-02 04B Fullerton Brt.wav
# 	00014-10-03 04B Fullerton Brt.wav
# 	00014-10-04 04B Fullerton Brt.wav
# 	00014-10-05 04B Fullerton Brt.wav
# 	00014-10-06 04B Fullerton Brt.wav
# 	00014-10-07 04B Fullerton Brt.wav
# 00014-02 04B Fullerton Brt.wav
# 	00014-02-00 04B Fullerton Brt.wav
# 	00014-02-01 04B Fullerton Brt.wav
# 	00014-02-02 04B Fullerton Brt.wav
# 	00014-02-03 04B Fullerton Brt.wav
# 	00014-02-04 04B Fullerton Brt.wav
# 	00014-02-05 04B Fullerton Brt.wav
# 	00014-02-06 04B Fullerton Brt.wav
# 	00014-02-07 04B Fullerton Brt.wav
# 	00014-02-08 04B Fullerton Brt.wav
# 	00014-02-09 04B Fullerton Brt.wav
# 	00014-02-10 04B Fullerton Brt.wav
# 	00014-02-11 04B Fullerton Brt.wav
# 00014-12 04B Fullerton Brt.wav
# 	00014-12-00 04B Fullerton Brt.wav
# 	00014-12-01 04B Fullerton Brt.wav
# 	00014-12-02 04B Fullerton Brt.wav
# 	00014-12-03 04B Fullerton Brt.wav
# 	00014-12-04 04B Fullerton Brt.wav
# 	00014-12-05 04B Fullerton Brt.wav
# 	00014-12-06 04B Fullerton Brt.wav
# 	00014-12-07 04B Fullerton Brt.wav
# 	00014-12-08 04B Fullerton Brt.wav
# 	00014-12-09 04B Fullerton Brt.wav
# 	00014-12-10 04B Fullerton Brt.wav
# 	00014-12-11 04B Fullerton Brt.wav
# 	00014-12-12 04B Fullerton Brt.wav
# 	00014-12-13 04B Fullerton Brt.wav
# 	00014-12-14 04B Fullerton Brt.wav
# 00014-03 04B Fullerton Brt.wav
# 	00014-03-00 04B Fullerton Brt.wav
# 	00014-03-01 04B Fullerton Brt.wav
# 	00014-03-02 04B Fullerton Brt.wav
# 	00014-03-03 04B Fullerton Brt.wav
# 	00014-03-04 04B Fullerton Brt.wav
# 	00014-03-05 04B Fullerton Brt.wav
# 	00014-03-06 04B Fullerton Brt.wav
# 	00014-03-07 04B Fullerton Brt.wav
# 	00014-03-08 04B Fullerton Brt.wav
# 	00014-03-09 04B Fullerton Brt.wav
# 	00014-03-10 04B Fullerton Brt.wav
# 	00014-03-11 04B Fullerton Brt.wav
# 	00014-03-12 04B Fullerton Brt.wav
# 00014-05 04B Fullerton Brt.wav
# 	00014-05-00 04B Fullerton Brt.wav
# 	00014-05-01 04B Fullerton Brt.wav
# 	00014-05-02 04B Fullerton Brt.wav
# 	00014-05-03 04B Fullerton Brt.wav
# 	00014-05-04 04B Fullerton Brt.wav
# 	00014-05-05 04B Fullerton Brt.wav
# 	00014-05-06 04B Fullerton Brt.wav
# 	00014-05-07 04B Fullerton Brt.wav
# 	00014-05-08 04B Fullerton Brt.wav
# 	00014-05-09 04B Fullerton Brt.wav
# 	00014-05-10 04B Fullerton Brt.wav
# 00014-11 04B Fullerton Brt.wav
# 	00014-11-00 04B Fullerton Brt.wav
# 	00014-11-01 04B Fullerton Brt.wav
# 	00014-11-02 04B Fullerton Brt.wav
# 	00014-11-03 04B Fullerton Brt.wav
# 	00014-11-04 04B Fullerton Brt.wav
# 	00014-11-05 04B Fullerton Brt.wav
# 	00014-11-06 04B Fullerton Brt.wav
# 	00014-11-07 04B Fullerton Brt.wav
# 	00014-11-08 04B Fullerton Brt.wav
# 00015-06 04C Brit J45 Brt.wav
# 	00015-06-00 04C Brit J45 Brt.wav
# 	00015-06-01 04C Brit J45 Brt.wav
# 	00015-06-02 04C Brit J45 Brt.wav
# 	00015-06-03 04C Brit J45 Brt.wav
# 	00015-06-04 04C Brit J45 Brt.wav
# 	00015-06-05 04C Brit J45 Brt.wav
# 	00015-06-06 04C Brit J45 Brt.wav
# 	00015-06-07 04C Brit J45 Brt.wav
# 	00015-06-08 04C Brit J45 Brt.wav
# 	00015-06-09 04C Brit J45 Brt.wav
# 	00015-06-10 04C Brit J45 Brt.wav
# 	00015-06-11 04C Brit J45 Brt.wav
# 	00015-06-12 04C Brit J45 Brt.wav
# 	00015-06-13 04C Brit J45 Brt.wav
# 00015-10 04C Brit J45 Brt.wav
# 	00015-10-00 04C Brit J45 Brt.wav
# 	00015-10-01 04C Brit J45 Brt.wav
# 	00015-10-02 04C Brit J45 Brt.wav
# 	00015-10-03 04C Brit J45 Brt.wav
# 	00015-10-04 04C Brit J45 Brt.wav
# 	00015-10-05 04C Brit J45 Brt.wav
# 	00015-10-06 04C Brit J45 Brt.wav
# 	00015-10-07 04C Brit J45 Brt.wav
# 00015-12 04C Brit J45 Brt.wav
# 	00015-12-00 04C Brit J45 Brt.wav
# 	00015-12-01 04C Brit J45 Brt.wav
# 	00015-12-02 04C Brit J45 Brt.wav
# 	00015-12-03 04C Brit J45 Brt.wav
# 	00015-12-04 04C Brit J45 Brt.wav
# 	00015-12-05 04C Brit J45 Brt.wav
# 	00015-12-06 04C Brit J45 Brt.wav
# 	00015-12-07 04C Brit J45 Brt.wav
# 	00015-12-08 04C Brit J45 Brt.wav
# 	00015-12-09 04C Brit J45 Brt.wav
# 	00015-12-10 04C Brit J45 Brt.wav
# 	00015-12-11 04C Brit J45 Brt.wav
# 	00015-12-12 04C Brit J45 Brt.wav
# 	00015-12-13 04C Brit J45 Brt.wav
# 	00015-12-14 04C Brit J45 Brt.wav
# 00015-01 04C Brit J45 Brt.wav
# 	00015-01-00 04C Brit J45 Brt.wav
# 	00015-01-01 04C Brit J45 Brt.wav
# 	00015-01-02 04C Brit J45 Brt.wav
# 	00015-01-03 04C Brit J45 Brt.wav
# 	00015-01-04 04C Brit J45 Brt.wav
# 	00015-01-05 04C Brit J45 Brt.wav
# 	00015-01-06 04C Brit J45 Brt.wav
# 	00015-01-07 04C Brit J45 Brt.wav
# 	00015-01-08 04C Brit J45 Brt.wav
# 	00015-01-09 04C Brit J45 Brt.wav
# 	00015-01-10 04C Brit J45 Brt.wav
# 	00015-01-11 04C Brit J45 Brt.wav
# 	00015-01-12 04C Brit J45 Brt.wav
# 00015-09 04C Brit J45 Brt.wav
# 	00015-09-00 04C Brit J45 Brt.wav
# 	00015-09-01 04C Brit J45 Brt.wav
# 	00015-09-02 04C Brit J45 Brt.wav
# 	00015-09-03 04C Brit J45 Brt.wav
# 	00015-09-04 04C Brit J45 Brt.wav
# 	00015-09-05 04C Brit J45 Brt.wav
# 	00015-09-06 04C Brit J45 Brt.wav
# 	00015-09-07 04C Brit J45 Brt.wav
# 	00015-09-08 04C Brit J45 Brt.wav
# 	00015-09-09 04C Brit J45 Brt.wav
# 	00015-09-10 04C Brit J45 Brt.wav
# 00015-11 04C Brit J45 Brt.wav
# 	00015-11-00 04C Brit J45 Brt.wav
# 	00015-11-01 04C Brit J45 Brt.wav
# 	00015-11-02 04C Brit J45 Brt.wav
# 	00015-11-03 04C Brit J45 Brt.wav
# 	00015-11-04 04C Brit J45 Brt.wav
# 	00015-11-05 04C Brit J45 Brt.wav
# 	00015-11-06 04C Brit J45 Brt.wav
# 	00015-11-07 04C Brit J45 Brt.wav
# 	00015-11-08 04C Brit J45 Brt.wav
# 00015-05 04C Brit J45 Brt.wav
# 	00015-05-00 04C Brit J45 Brt.wav
# 	00015-05-01 04C Brit J45 Brt.wav
# 	00015-05-02 04C Brit J45 Brt.wav
# 	00015-05-03 04C Brit J45 Brt.wav
# 	00015-05-04 04C Brit J45 Brt.wav
# 	00015-05-05 04C Brit J45 Brt.wav
# 	00015-05-06 04C Brit J45 Brt.wav
# 	00015-05-07 04C Brit J45 Brt.wav
# 	00015-05-08 04C Brit J45 Brt.wav
# 	00015-05-09 04C Brit J45 Brt.wav
# 	00015-05-10 04C Brit J45 Brt.wav
# 00015-08 04C Brit J45 Brt.wav
# 	00015-08-00 04C Brit J45 Brt.wav
# 	00015-08-01 04C Brit J45 Brt.wav
# 	00015-08-02 04C Brit J45 Brt.wav
# 	00015-08-03 04C Brit J45 Brt.wav
# 	00015-08-04 04C Brit J45 Brt.wav
# 	00015-08-05 04C Brit J45 Brt.wav
# 	00015-08-06 04C Brit J45 Brt.wav
# 	00015-08-07 04C Brit J45 Brt.wav
# 	00015-08-08 04C Brit J45 Brt.wav
# 	00015-08-09 04C Brit J45 Brt.wav
# 	00015-08-10 04C Brit J45 Brt.wav
# 	00015-08-11 04C Brit J45 Brt.wav
# 	00015-08-12 04C Brit J45 Brt.wav
# 	00015-08-13 04C Brit J45 Brt.wav
# 00015-04 04C Brit J45 Brt.wav
# 	00015-04-00 04C Brit J45 Brt.wav
# 	00015-04-01 04C Brit J45 Brt.wav
# 	00015-04-02 04C Brit J45 Brt.wav
# 	00015-04-03 04C Brit J45 Brt.wav
# 	00015-04-04 04C Brit J45 Brt.wav
# 	00015-04-05 04C Brit J45 Brt.wav
# 	00015-04-06 04C Brit J45 Brt.wav
# 	00015-04-07 04C Brit J45 Brt.wav
# 	00015-04-08 04C Brit J45 Brt.wav
# 	00015-04-09 04C Brit J45 Brt.wav
# 	00015-04-10 04C Brit J45 Brt.wav
# 00015-07 04C Brit J45 Brt.wav
# 	00015-07-00 04C Brit J45 Brt.wav
# 	00015-07-01 04C Brit J45 Brt.wav
# 	00015-07-02 04C Brit J45 Brt.wav
# 	00015-07-03 04C Brit J45 Brt.wav
# 	00015-07-04 04C Brit J45 Brt.wav
# 	00015-07-05 04C Brit J45 Brt.wav
# 	00015-07-06 04C Brit J45 Brt.wav
# 	00015-07-07 04C Brit J45 Brt.wav
# 	00015-07-08 04C Brit J45 Brt.wav
# 	00015-07-09 04C Brit J45 Brt.wav
# 	00015-07-10 04C Brit J45 Brt.wav
# 00015-02 04C Brit J45 Brt.wav
# 	00015-02-00 04C Brit J45 Brt.wav
# 	00015-02-01 04C Brit J45 Brt.wav
# 	00015-02-02 04C Brit J45 Brt.wav
# 	00015-02-03 04C Brit J45 Brt.wav
# 	00015-02-04 04C Brit J45 Brt.wav
# 	00015-02-05 04C Brit J45 Brt.wav
# 	00015-02-06 04C Brit J45 Brt.wav
# 	00015-02-07 04C Brit J45 Brt.wav
# 	00015-02-08 04C Brit J45 Brt.wav
# 	00015-02-09 04C Brit J45 Brt.wav
# 	00015-02-10 04C Brit J45 Brt.wav
# 	00015-02-11 04C Brit J45 Brt.wav
# 00015-03 04C Brit J45 Brt.wav
# 	00015-03-00 04C Brit J45 Brt.wav
# 	00015-03-01 04C Brit J45 Brt.wav
# 	00015-03-02 04C Brit J45 Brt.wav
# 	00015-03-03 04C Brit J45 Brt.wav
# 	00015-03-04 04C Brit J45 Brt.wav
# 	00015-03-05 04C Brit J45 Brt.wav
# 	00015-03-06 04C Brit J45 Brt.wav
# 	00015-03-07 04C Brit J45 Brt.wav
# 	00015-03-08 04C Brit J45 Brt.wav
# 	00015-03-09 04C Brit J45 Brt.wav
# 	00015-03-10 04C Brit J45 Brt.wav
# 	00015-03-11 04C Brit J45 Brt.wav
# 	00015-03-12 04C Brit J45 Brt.wav
# 00016-07 04D Solo Lead OD.wav
# 	00016-07-00 04D Solo Lead OD.wav
# 	00016-07-01 04D Solo Lead OD.wav
# 	00016-07-02 04D Solo Lead OD.wav
# 	00016-07-03 04D Solo Lead OD.wav
# 	00016-07-04 04D Solo Lead OD.wav
# 	00016-07-05 04D Solo Lead OD.wav
# 	00016-07-06 04D Solo Lead OD.wav
# 	00016-07-07 04D Solo Lead OD.wav
# 	00016-07-08 04D Solo Lead OD.wav
# 	00016-07-09 04D Solo Lead OD.wav
# 	00016-07-10 04D Solo Lead OD.wav
# 00016-01 04D Solo Lead OD.wav
# 	00016-01-00 04D Solo Lead OD.wav
# 	00016-01-01 04D Solo Lead OD.wav
# 	00016-01-02 04D Solo Lead OD.wav
# 	00016-01-03 04D Solo Lead OD.wav
# 	00016-01-04 04D Solo Lead OD.wav
# 	00016-01-05 04D Solo Lead OD.wav
# 	00016-01-06 04D Solo Lead OD.wav
# 	00016-01-07 04D Solo Lead OD.wav
# 	00016-01-08 04D Solo Lead OD.wav
# 	00016-01-09 04D Solo Lead OD.wav
# 	00016-01-10 04D Solo Lead OD.wav
# 	00016-01-11 04D Solo Lead OD.wav
# 	00016-01-12 04D Solo Lead OD.wav
# 00016-11 04D Solo Lead OD.wav
# 	00016-11-00 04D Solo Lead OD.wav
# 	00016-11-01 04D Solo Lead OD.wav
# 	00016-11-02 04D Solo Lead OD.wav
# 	00016-11-03 04D Solo Lead OD.wav
# 	00016-11-04 04D Solo Lead OD.wav
# 	00016-11-05 04D Solo Lead OD.wav
# 	00016-11-06 04D Solo Lead OD.wav
# 	00016-11-07 04D Solo Lead OD.wav
# 	00016-11-08 04D Solo Lead OD.wav
# 00016-05 04D Solo Lead OD.wav
# 	00016-05-00 04D Solo Lead OD.wav
# 	00016-05-01 04D Solo Lead OD.wav
# 	00016-05-02 04D Solo Lead OD.wav
# 	00016-05-03 04D Solo Lead OD.wav
# 	00016-05-04 04D Solo Lead OD.wav
# 	00016-05-05 04D Solo Lead OD.wav
# 	00016-05-06 04D Solo Lead OD.wav
# 	00016-05-07 04D Solo Lead OD.wav
# 	00016-05-08 04D Solo Lead OD.wav
# 	00016-05-09 04D Solo Lead OD.wav
# 	00016-05-10 04D Solo Lead OD.wav
# 00016-10 04D Solo Lead OD.wav
# 	00016-10-00 04D Solo Lead OD.wav
# 	00016-10-01 04D Solo Lead OD.wav
# 	00016-10-02 04D Solo Lead OD.wav
# 	00016-10-03 04D Solo Lead OD.wav
# 	00016-10-04 04D Solo Lead OD.wav
# 	00016-10-05 04D Solo Lead OD.wav
# 	00016-10-06 04D Solo Lead OD.wav
# 	00016-10-07 04D Solo Lead OD.wav
# 00016-09 04D Solo Lead OD.wav
# 	00016-09-00 04D Solo Lead OD.wav
# 	00016-09-01 04D Solo Lead OD.wav
# 	00016-09-02 04D Solo Lead OD.wav
# 	00016-09-03 04D Solo Lead OD.wav
# 	00016-09-04 04D Solo Lead OD.wav
# 	00016-09-05 04D Solo Lead OD.wav
# 	00016-09-06 04D Solo Lead OD.wav
# 	00016-09-07 04D Solo Lead OD.wav
# 	00016-09-08 04D Solo Lead OD.wav
# 	00016-09-09 04D Solo Lead OD.wav
# 	00016-09-10 04D Solo Lead OD.wav
# 00016-02 04D Solo Lead OD.wav
# 	00016-02-00 04D Solo Lead OD.wav
# 	00016-02-01 04D Solo Lead OD.wav
# 	00016-02-02 04D Solo Lead OD.wav
# 	00016-02-03 04D Solo Lead OD.wav
# 	00016-02-04 04D Solo Lead OD.wav
# 	00016-02-05 04D Solo Lead OD.wav
# 	00016-02-06 04D Solo Lead OD.wav
# 	00016-02-07 04D Solo Lead OD.wav
# 	00016-02-08 04D Solo Lead OD.wav
# 	00016-02-09 04D Solo Lead OD.wav
# 	00016-02-10 04D Solo Lead OD.wav
# 	00016-02-11 04D Solo Lead OD.wav
# 00016-06 04D Solo Lead OD.wav
# 	00016-06-00 04D Solo Lead OD.wav
# 	00016-06-01 04D Solo Lead OD.wav
# 	00016-06-02 04D Solo Lead OD.wav
# 	00016-06-03 04D Solo Lead OD.wav
# 	00016-06-04 04D Solo Lead OD.wav
# 	00016-06-05 04D Solo Lead OD.wav
# 	00016-06-06 04D Solo Lead OD.wav
# 	00016-06-07 04D Solo Lead OD.wav
# 	00016-06-08 04D Solo Lead OD.wav
# 	00016-06-09 04D Solo Lead OD.wav
# 	00016-06-10 04D Solo Lead OD.wav
# 	00016-06-11 04D Solo Lead OD.wav
# 	00016-06-12 04D Solo Lead OD.wav
# 	00016-06-13 04D Solo Lead OD.wav
# 00016-08 04D Solo Lead OD.wav
# 	00016-08-00 04D Solo Lead OD.wav
# 	00016-08-01 04D Solo Lead OD.wav
# 	00016-08-02 04D Solo Lead OD.wav
# 	00016-08-03 04D Solo Lead OD.wav
# 	00016-08-04 04D Solo Lead OD.wav
# 	00016-08-05 04D Solo Lead OD.wav
# 	00016-08-06 04D Solo Lead OD.wav
# 	00016-08-07 04D Solo Lead OD.wav
# 	00016-08-08 04D Solo Lead OD.wav
# 	00016-08-09 04D Solo Lead OD.wav
# 	00016-08-10 04D Solo Lead OD.wav
# 	00016-08-11 04D Solo Lead OD.wav
# 	00016-08-12 04D Solo Lead OD.wav
# 	00016-08-13 04D Solo Lead OD.wav
# 00016-03 04D Solo Lead OD.wav
# 	00016-03-00 04D Solo Lead OD.wav
# 	00016-03-01 04D Solo Lead OD.wav
# 	00016-03-02 04D Solo Lead OD.wav
# 	00016-03-03 04D Solo Lead OD.wav
# 	00016-03-04 04D Solo Lead OD.wav
# 	00016-03-05 04D Solo Lead OD.wav
# 	00016-03-06 04D Solo Lead OD.wav
# 	00016-03-07 04D Solo Lead OD.wav
# 	00016-03-08 04D Solo Lead OD.wav
# 	00016-03-09 04D Solo Lead OD.wav
# 	00016-03-10 04D Solo Lead OD.wav
# 	00016-03-11 04D Solo Lead OD.wav
# 	00016-03-12 04D Solo Lead OD.wav
# 00016-04 04D Solo Lead OD.wav
# 	00016-04-00 04D Solo Lead OD.wav
# 	00016-04-01 04D Solo Lead OD.wav
# 	00016-04-02 04D Solo Lead OD.wav
# 	00016-04-03 04D Solo Lead OD.wav
# 	00016-04-04 04D Solo Lead OD.wav
# 	00016-04-05 04D Solo Lead OD.wav
# 	00016-04-06 04D Solo Lead OD.wav
# 	00016-04-07 04D Solo Lead OD.wav
# 	00016-04-08 04D Solo Lead OD.wav
# 	00016-04-09 04D Solo Lead OD.wav
# 	00016-04-10 04D Solo Lead OD.wav
# 00016-12 04D Solo Lead OD.wav
# 	00016-12-00 04D Solo Lead OD.wav
# 	00016-12-01 04D Solo Lead OD.wav
# 	00016-12-02 04D Solo Lead OD.wav
# 	00016-12-03 04D Solo Lead OD.wav
# 	00016-12-04 04D Solo Lead OD.wav
# 	00016-12-05 04D Solo Lead OD.wav
# 	00016-12-06 04D Solo Lead OD.wav
# 	00016-12-07 04D Solo Lead OD.wav
# 	00016-12-08 04D Solo Lead OD.wav
# 	00016-12-09 04D Solo Lead OD.wav
# 	00016-12-10 04D Solo Lead OD.wav
# 	00016-12-11 04D Solo Lead OD.wav
# 	00016-12-12 04D Solo Lead OD.wav
# 	00016-12-13 04D Solo Lead OD.wav
# 	00016-12-14 04D Solo Lead OD.wav
# 00017-05 05A Placater Clean.wav
# 	00017-05-00 05A Placater Clean.wav
# 	00017-05-01 05A Placater Clean.wav
# 	00017-05-02 05A Placater Clean.wav
# 	00017-05-03 05A Placater Clean.wav
# 	00017-05-04 05A Placater Clean.wav
# 	00017-05-05 05A Placater Clean.wav
# 	00017-05-06 05A Placater Clean.wav
# 	00017-05-07 05A Placater Clean.wav
# 	00017-05-08 05A Placater Clean.wav
# 	00017-05-09 05A Placater Clean.wav
# 	00017-05-10 05A Placater Clean.wav
# 00017-11 05A Placater Clean.wav
# 	00017-11-00 05A Placater Clean.wav
# 	00017-11-01 05A Placater Clean.wav
# 	00017-11-02 05A Placater Clean.wav
# 	00017-11-03 05A Placater Clean.wav
# 	00017-11-04 05A Placater Clean.wav
# 	00017-11-05 05A Placater Clean.wav
# 	00017-11-06 05A Placater Clean.wav
# 	00017-11-07 05A Placater Clean.wav
# 	00017-11-08 05A Placater Clean.wav
# 00017-03 05A Placater Clean.wav
# 	00017-03-00 05A Placater Clean.wav
# 	00017-03-01 05A Placater Clean.wav
# 	00017-03-02 05A Placater Clean.wav
# 	00017-03-03 05A Placater Clean.wav
# 	00017-03-04 05A Placater Clean.wav
# 	00017-03-05 05A Placater Clean.wav
# 	00017-03-06 05A Placater Clean.wav
# 	00017-03-07 05A Placater Clean.wav
# 	00017-03-08 05A Placater Clean.wav
# 	00017-03-09 05A Placater Clean.wav
# 	00017-03-10 05A Placater Clean.wav
# 	00017-03-11 05A Placater Clean.wav
# 	00017-03-12 05A Placater Clean.wav
# 00017-07 05A Placater Clean.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-748ea8693e89> in <module>()
#      49             print(file)
#      50             number_of_clips -= 1
# ---> 51             y, sr = librosa.load(os.path.join(AUDIO_FILES_DIR, file), sr=SAMPLE_RATE, mono=MONO)
#      52             duration = librosa.get_duration(y=y, sr=sr)
#      53             window_id = 0
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     147
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#     151             if offset:
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     627         self._info = _create_info_struct(file, mode, samplerate, channels,
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#     631             # Move write position to 0 (like in Python file objects)
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1173                 else:
#    1174                     file = file.encode(_sys.getfilesystemencoding())
# -> 1175             file_ptr = openfunction(file, mode_int, self._info)
#    1176         elif isinstance(file, int):
#    1177             file_ptr = _snd.sf_open_fd(file, mode_int, self._info, closefd)
#
# KeyboardInterrupt:

# %%
print(files)
# Out:
# ['00001-11 01A US Double Nrm.wav', '00001-04 01A US Double Nrm.wav', '00001-06 01A US Double Nrm.wav', '00001-09 01A US Double Nrm.wav', '00001-05 01A US Double Nrm.wav', '00001-12 01A US Double Nrm.wav', '00001-02 01A US Double Nrm.wav', '00001-01 01A US Double Nrm.wav', '00001-07 01A US Double Nrm.wav', '00001-10 01A US Double Nrm.wav', '00001-03 01A US Double Nrm.wav', '00001-08 01A US Double Nrm.wav', '00002-09 01B Essex A30.wav', '00002-05 01B Essex A30.wav', '00002-04 01B Essex A30.wav', '00002-01 01B Essex A30.wav', '00002-11 01B Essex A30.wav', '00002-06 01B Essex A30.wav', '00002-12 01B Essex A30.wav', '00002-08 01B Essex A30.wav', '00002-07 01B Essex A30.wav', '00002-10 01B Essex A30.wav', '00002-02 01B Essex A30.wav', '00002-03 01B Essex A30.wav', '00003-09 01C Brit Plexi Jump.wav', '00003-06 01C Brit Plexi Jump.wav', '00003-11 01C Brit Plexi Jump.wav', '00003-10 01C Brit Plexi Jump.wav', '00003-05 01C Brit Plexi Jump.wav', '00003-12 01C Brit Plexi Jump.wav', '00003-08 01C Brit Plexi Jump.wav', '00003-01 01C Brit Plexi Jump.wav', '00003-07 01C Brit Plexi Jump.wav', '00003-03 01C Brit Plexi Jump.wav', '00003-02 01C Brit Plexi Jump.wav', '00003-04 01C Brit Plexi Jump.wav', '00004-04 01D Cali Rectifire.wav', '00004-12 01D Cali Rectifire.wav', '00004-07 01D Cali Rectifire.wav', '00004-06 01D Cali Rectifire.wav', '00004-11 01D Cali Rectifire.wav', '00004-03 01D Cali Rectifire.wav', '00004-10 01D Cali Rectifire.wav', '00004-02 01D Cali Rectifire.wav', '00004-08 01D Cali Rectifire.wav', '00004-05 01D Cali Rectifire.wav', '00004-09 01D Cali Rectifire.wav', '00004-01 01D Cali Rectifire.wav', '00005-12 02A US Deluxe Nrm.wav', '00005-01 02A US Deluxe Nrm.wav', '00005-07 02A US Deluxe Nrm.wav', '00005-06 02A US Deluxe Nrm.wav', '00005-08 02A US Deluxe Nrm.wav', '00005-11 02A US Deluxe Nrm.wav', '00005-04 02A US Deluxe Nrm.wav', '00005-03 02A US Deluxe Nrm.wav', '00005-09 02A US Deluxe Nrm.wav', '00005-05 02A US Deluxe Nrm.wav', '00005-02 02A US Deluxe Nrm.wav', '00005-10 02A US Deluxe Nrm.wav', '00006-07 02B A30 Fawn Nrm.wav', '00006-11 02B A30 Fawn Nrm.wav', '00006-06 02B A30 Fawn Nrm.wav', '00006-08 02B A30 Fawn Nrm.wav', '00006-10 02B A30 Fawn Nrm.wav', '00006-01 02B A30 Fawn Nrm.wav', '00006-12 02B A30 Fawn Nrm.wav', '00006-09 02B A30 Fawn Nrm.wav', '00006-04 02B A30 Fawn Nrm.wav', '00006-02 02B A30 Fawn Nrm.wav', '00006-03 02B A30 Fawn Nrm.wav', '00006-05 02B A30 Fawn Nrm.wav', '00007-06 02C Revv Gen Purple.wav', '00007-04 02C Revv Gen Purple.wav', '00007-10 02C Revv Gen Purple.wav', '00007-11 02C Revv Gen Purple.wav', '00007-08 02C Revv Gen Purple.wav', '00007-01 02C Revv Gen Purple.wav', '00007-05 02C Revv Gen Purple.wav', '00007-07 02C Revv Gen Purple.wav', '00007-02 02C Revv Gen Purple.wav', '00007-09 02C Revv Gen Purple.wav', '00007-12 02C Revv Gen Purple.wav', '00007-03 02C Revv Gen Purple.wav', '00008-11 02D Revv Gen Red.wav', '00008-10 02D Revv Gen Red.wav', '00008-09 02D Revv Gen Red.wav', '00008-05 02D Revv Gen Red.wav', '00008-01 02D Revv Gen Red.wav', '00008-12 02D Revv Gen Red.wav', '00008-08 02D Revv Gen Red.wav', '00008-03 02D Revv Gen Red.wav', '00008-07 02D Revv Gen Red.wav', '00008-06 02D Revv Gen Red.wav', '00008-02 02D Revv Gen Red.wav', '00008-04 02D Revv Gen Red.wav', '00009-06 03A Archetype Clean.wav', '00009-12 03A Archetype Clean.wav', '00009-07 03A Archetype Clean.wav', '00009-09 03A Archetype Clean.wav', '00009-11 03A Archetype Clean.wav', '00009-08 03A Archetype Clean.wav', '00009-05 03A Archetype Clean.wav', '00009-02 03A Archetype Clean.wav', '00009-04 03A Archetype Clean.wav', '00009-10 03A Archetype Clean.wav', '00009-03 03A Archetype Clean.wav', '00009-01 03A Archetype Clean.wav', '00010-10 03B Matchstick Ch1.wav', '00010-06 03B Matchstick Ch1.wav', '00010-09 03B Matchstick Ch1.wav', '00010-02 03B Matchstick Ch1.wav', '00010-03 03B Matchstick Ch1.wav', '00010-12 03B Matchstick Ch1.wav', '00010-07 03B Matchstick Ch1.wav', '00010-01 03B Matchstick Ch1.wav', '00010-08 03B Matchstick Ch1.wav',  ...
